# %%
import os
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from sklearn.model_selection import train_test_split
from PIL import Image
from tensorflow.keras.layers import Conv2D
import sys
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Flatten
from keras.layers import MaxPooling2D
from keras.layers import Conv2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import np_utils
import numpy as np
# load ascii text and covert to lowercase
from keras.models import load_model
import matplotlib.pyplot as plt
from keras.layers.normalization import BatchNormalization
import math
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from numpy import array
from numpy import argmax
from datetime import datetime
# Out:
# Using TensorFlow backend.

# %%
datasetPath ="Dataset/"
modelName = "bestmodel.h5"
checkpoint = "bestModelTextGen.hdf5"
nEpocas = 40
steps_per_epoch = 5
VALIDATION_SIZE = 1
BATCH_SIZE = 8
IMG_SIZE = 200

# %%
imagePath = []
y = []
X = []

print("Carrega dataset")
for root, dirs, files in os.walk(datasetPath):
    for dir in dirs:
        for root2, dirs2, files2 in os.walk(datasetPath+dir):
            for file in files2:
                imagePath.append(datasetPath+dir+"/"+file)
                y.append(dir)
                photo = img_to_array(load_img(datasetPath+dir+"/"+file, target_size=(IMG_SIZE, IMG_SIZE)))
                X.append(photo)
print("Fim - Carrega dataset")
# Out:
# Carrega dataset
# Fim - Carrega dataset

# %%
#Classificacao

numpy.unique(y, return_counts=True)
# Out:
# (array(['COINS', 'PAINTINGS', 'PRINTS', 'SCULPTURE', 'TEXTILES'],
#        dtype='<U9'), array([102, 102, 101, 101, 101], dtype=int64))

# %%
im = Image.open(imagePath[0])
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x478 at 0x1D8048D3908>

# %%
im = Image.open(imagePath[40])
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x478 at 0x1D830864DA0>

# %%
im = Image.open(imagePath[80])
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x478 at 0x1D830864F60>

# %%
print("Ajeita os dados")
X = numpy.asarray(X)
numberClasses = len(np.unique(y))
count = len(y)
values = array(y)
# integer encode
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(values)
# binary encode
onehot_encoder = OneHotEncoder(sparse=False)
integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
y = onehot_encoder.fit_transform(integer_encoded)
print("Fim - Ajeita os dados")

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.5, random_state=42)
# Out:
# Ajeita os dados
# Fim - Ajeita os dados
# c:\users\t-gamer\documents\git\objectclassification\projectgpu\venv\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
print("Arquitetura")
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(IMG_SIZE, IMG_SIZE, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Dropout(0.4))



model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dense(numberClasses, activation='softmax'))
# load the network weights
print("Fim - Arquitetura")

if os.path.isfile(checkpoint):
	model.load_weights(checkpoint)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics = ['accuracy'])
# define the checkpoint
#filepath="weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"

mc = ModelCheckpoint(checkpoint, monitor='loss', verbose=1, save_best_only=True, mode='min')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100, min_delta=0.000001)

# fit the model
compute_steps_per_epoch = lambda x: int(math.ceil(1. * x / BATCH_SIZE))
val_steps = compute_steps_per_epoch(VALIDATION_SIZE)
history = model.fit( X_train, y_train, epochs=nEpocas, steps_per_epoch=steps_per_epoch, callbacks=[es, mc], validation_steps = val_steps, validation_data=(X_test, y_test))
# Out:
# Arquitetura
# Fim - Arquitetura
# Train on 253 samples, validate on 254 samples
# Epoch 1/40
# 5/5 [==============================] - 4s 761ms/step - loss: 1.5380 - acc: 0.3502 - val_loss: 1.2457 - val_acc: 0.5039
#
# Epoch 00001: loss improved from inf to 1.53804, saving model to bestModelTextGen.hdf5
# Epoch 2/40
# 5/5 [==============================] - 2s 466ms/step - loss: 1.0662 - acc: 0.5273 - val_loss: 1.0679 - val_acc: 0.5906
#
# Epoch 00002: loss improved from 1.53804 to 1.06620, saving model to bestModelTextGen.hdf5
# Epoch 3/40
# 5/5 [==============================] - 2s 467ms/step - loss: 0.8456 - acc: 0.6949 - val_loss: 0.9637 - val_acc: 0.6614
#
# Epoch 00003: loss improved from 1.06620 to 0.84560, saving model to bestModelTextGen.hdf5
# Epoch 4/40
# 5/5 [==============================] - 2s 463ms/step - loss: 0.6813 - acc: 0.7660 - val_loss: 0.9412 - val_acc: 0.6220
#
# Epoch 00004: loss improved from 0.84560 to 0.68126, saving model to bestModelTextGen.hdf5
# Epoch 5/40
# 5/5 [==============================] - 2s 468ms/step - loss: 0.5614 - acc: 0.8261 - val_loss: 0.9239 - val_acc: 0.6457
#
# Epoch 00005: loss improved from 0.68126 to 0.56140, saving model to bestModelTextGen.hdf5
# Epoch 6/40
# 5/5 [==============================] - 2s 468ms/step - loss: 0.4529 - acc: 0.8854 - val_loss: 0.9231 - val_acc: 0.6614
#
# Epoch 00006: loss improved from 0.56140 to 0.45288, saving model to bestModelTextGen.hdf5
# Epoch 7/40
# 5/5 [==============================] - 2s 462ms/step - loss: 0.3542 - acc: 0.9328 - val_loss: 0.9235 - val_acc: 0.6535
#
# Epoch 00007: loss improved from 0.45288 to 0.35417, saving model to bestModelTextGen.hdf5
# Epoch 8/40
# 5/5 [==============================] - 2s 463ms/step - loss: 0.2797 - acc: 0.9636 - val_loss: 0.8993 - val_acc: 0.6772
#
# Epoch 00008: loss improved from 0.35417 to 0.27968, saving model to bestModelTextGen.hdf5
# Epoch 9/40
# 5/5 [==============================] - 2s 462ms/step - loss: 0.2327 - acc: 0.9763 - val_loss: 0.8418 - val_acc: 0.6732
#
# Epoch 00009: loss improved from 0.27968 to 0.23273, saving model to bestModelTextGen.hdf5
# Epoch 10/40
# 5/5 [==============================] - 2s 462ms/step - loss: 0.1927 - acc: 0.9834 - val_loss: 0.7971 - val_acc: 0.7126
#
# Epoch 00010: loss improved from 0.23273 to 0.19267, saving model to bestModelTextGen.hdf5
# Epoch 11/40
# 5/5 [==============================] - 2s 464ms/step - loss: 0.1604 - acc: 0.9921 - val_loss: 0.8103 - val_acc: 0.7244
#
# Epoch 00011: loss improved from 0.19267 to 0.16039, saving model to bestModelTextGen.hdf5
# Epoch 12/40
# 5/5 [==============================] - 2s 463ms/step - loss: 0.1214 - acc: 0.9953 - val_loss: 0.8227 - val_acc: 0.7323
#
# Epoch 00012: loss improved from 0.16039 to 0.12145, saving model to bestModelTextGen.hdf5
# Epoch 13/40
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0993 - acc: 0.9984 - val_loss: 0.7597 - val_acc: 0.7165
#
# Epoch 00013: loss improved from 0.12145 to 0.09926, saving model to bestModelTextGen.hdf5
# Epoch 14/40
# 5/5 [==============================] - 2s 473ms/step - loss: 0.0843 - acc: 0.9976 - val_loss: 0.8241 - val_acc: 0.7402
#
# Epoch 00014: loss improved from 0.09926 to 0.08432, saving model to bestModelTextGen.hdf5
# Epoch 15/40
# 5/5 [==============================] - 2s 465ms/step - loss: 0.0760 - acc: 0.9984 - val_loss: 0.8430 - val_acc: 0.7323
#
# Epoch 00015: loss improved from 0.08432 to 0.07605, saving model to bestModelTextGen.hdf5
# Epoch 16/40
# 5/5 [==============================] - 2s 463ms/step - loss: 0.0614 - acc: 1.0000 - val_loss: 0.7861 - val_acc: 0.7402
#
# Epoch 00016: loss improved from 0.07605 to 0.06139, saving model to bestModelTextGen.hdf5
# Epoch 17/40
# 5/5 [==============================] - 2s 473ms/step - loss: 0.0568 - acc: 0.9992 - val_loss: 0.8331 - val_acc: 0.7323
#
# Epoch 00017: loss improved from 0.06139 to 0.05676, saving model to bestModelTextGen.hdf5
# Epoch 18/40
# 5/5 [==============================] - 2s 488ms/step - loss: 0.0521 - acc: 0.9992 - val_loss: 0.7637 - val_acc: 0.7480
#
# Epoch 00018: loss improved from 0.05676 to 0.05206, saving model to bestModelTextGen.hdf5
# Epoch 19/40
# 5/5 [==============================] - 2s 476ms/step - loss: 0.0439 - acc: 1.0000 - val_loss: 0.8225 - val_acc: 0.7480
#
# Epoch 00019: loss improved from 0.05206 to 0.04392, saving model to bestModelTextGen.hdf5
# Epoch 20/40
# 5/5 [==============================] - 2s 484ms/step - loss: 0.0379 - acc: 1.0000 - val_loss: 0.8156 - val_acc: 0.7283
#
# Epoch 00020: loss improved from 0.04392 to 0.03787, saving model to bestModelTextGen.hdf5
# Epoch 21/40
# 5/5 [==============================] - 2s 467ms/step - loss: 0.0339 - acc: 0.9992 - val_loss: 0.8220 - val_acc: 0.7480
#
# Epoch 00021: loss improved from 0.03787 to 0.03390, saving model to bestModelTextGen.hdf5
# Epoch 22/40
# 5/5 [==============================] - 2s 475ms/step - loss: 0.0306 - acc: 1.0000 - val_loss: 0.7972 - val_acc: 0.7165
#
# Epoch 00022: loss improved from 0.03390 to 0.03060, saving model to bestModelTextGen.hdf5
# Epoch 23/40
# 5/5 [==============================] - 2s 469ms/step - loss: 0.0296 - acc: 1.0000 - val_loss: 0.8204 - val_acc: 0.7244
#
# Epoch 00023: loss improved from 0.03060 to 0.02959, saving model to bestModelTextGen.hdf5
# Epoch 24/40
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0249 - acc: 1.0000 - val_loss: 0.8540 - val_acc: 0.7402
#
# Epoch 00024: loss improved from 0.02959 to 0.02489, saving model to bestModelTextGen.hdf5
# Epoch 25/40
# 5/5 [==============================] - 2s 463ms/step - loss: 0.0268 - acc: 1.0000 - val_loss: 0.8922 - val_acc: 0.7165
#
# Epoch 00025: loss did not improve from 0.02489
# Epoch 26/40
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0240 - acc: 1.0000 - val_loss: 0.7589 - val_acc: 0.7598
#
# Epoch 00026: loss improved from 0.02489 to 0.02397, saving model to bestModelTextGen.hdf5
# Epoch 27/40
# 5/5 [==============================] - 2s 464ms/step - loss: 0.0205 - acc: 1.0000 - val_loss: 0.9145 - val_acc: 0.7480
#
# Epoch 00027: loss improved from 0.02397 to 0.02047, saving model to bestModelTextGen.hdf5
# Epoch 28/40
# 5/5 [==============================] - 2s 463ms/step - loss: 0.0238 - acc: 0.9992 - val_loss: 0.8100 - val_acc: 0.7480
#
# Epoch 00028: loss did not improve from 0.02047
# Epoch 29/40
# 5/5 [==============================] - 2s 465ms/step - loss: 0.0209 - acc: 1.0000 - val_loss: 0.8756 - val_acc: 0.7323
#
# Epoch 00029: loss did not improve from 0.02047
# Epoch 30/40
# 5/5 [==============================] - 2s 475ms/step - loss: 0.0203 - acc: 1.0000 - val_loss: 1.0063 - val_acc: 0.7165
#
# Epoch 00030: loss improved from 0.02047 to 0.02029, saving model to bestModelTextGen.hdf5
# Epoch 31/40
# 5/5 [==============================] - 2s 470ms/step - loss: 0.0196 - acc: 1.0000 - val_loss: 0.8253 - val_acc: 0.7520
#
# Epoch 00031: loss improved from 0.02029 to 0.01962, saving model to bestModelTextGen.hdf5
# Epoch 32/40
# 5/5 [==============================] - 2s 466ms/step - loss: 0.0187 - acc: 1.0000 - val_loss: 0.8442 - val_acc: 0.7480
#
# Epoch 00032: loss improved from 0.01962 to 0.01868, saving model to bestModelTextGen.hdf5
# Epoch 33/40
# 5/5 [==============================] - 2s 476ms/step - loss: 0.0146 - acc: 1.0000 - val_loss: 0.8924 - val_acc: 0.7362
#
# Epoch 00033: loss improved from 0.01868 to 0.01465, saving model to bestModelTextGen.hdf5
# Epoch 34/40
# 5/5 [==============================] - 2s 467ms/step - loss: 0.0137 - acc: 1.0000 - val_loss: 0.8590 - val_acc: 0.7441
#
# Epoch 00034: loss improved from 0.01465 to 0.01374, saving model to bestModelTextGen.hdf5
# Epoch 35/40
# 5/5 [==============================] - 2s 469ms/step - loss: 0.0134 - acc: 1.0000 - val_loss: 0.8537 - val_acc: 0.7441
#
# Epoch 00035: loss improved from 0.01374 to 0.01344, saving model to bestModelTextGen.hdf5
# Epoch 36/40
# 5/5 [==============================] - 2s 470ms/step - loss: 0.0134 - acc: 1.0000 - val_loss: 0.9706 - val_acc: 0.7323
#
# Epoch 00036: loss improved from 0.01344 to 0.01343, saving model to bestModelTextGen.hdf5
# Epoch 37/40
# 5/5 [==============================] - 2s 484ms/step - loss: 0.0134 - acc: 1.0000 - val_loss: 0.8661 - val_acc: 0.7441
#
# Epoch 00037: loss improved from 0.01343 to 0.01337, saving model to bestModelTextGen.hdf5
# Epoch 38/40
# 5/5 [==============================] - 2s 467ms/step - loss: 0.0134 - acc: 1.0000 - val_loss: 0.9127 - val_acc: 0.7402
#
# Epoch 00038: loss did not improve from 0.01337
# Epoch 39/40
# 5/5 [==============================] - 2s 466ms/step - loss: 0.0123 - acc: 1.0000 - val_loss: 0.8581 - val_acc: 0.7480
#
# Epoch 00039: loss improved from 0.01337 to 0.01229, saving model to bestModelTextGen.hdf5
# Epoch 40/40
# 5/5 [==============================] - 2s 472ms/step - loss: 0.0115 - acc: 1.0000 - val_loss: 0.8859 - val_acc: 0.7323
#
# Epoch 00040: loss improved from 0.01229 to 0.01154, saving model to bestModelTextGen.hdf5

# %%
time = datetime.now()
timestampStr = time.strftime("%d %b %Y %H %M %S %f)")
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\t-gamer\\documents\\git\\objectclassification\\projectgpu\\venv\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.clf()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig("loss"+timestampStr+".png")
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\t-gamer\\documents\\git\\objectclassification\\projectgpu\\venv\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
print("Saved model to disk")
model.save(modelName)
# Out:
# Saved model to disk
