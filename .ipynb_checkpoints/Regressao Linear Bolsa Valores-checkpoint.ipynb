# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import math
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend as K
import matplotlib.dates as dates
from sklearn.preprocessing import MinMaxScaler
import requests

# %%
urlPost = "https://marketdata.websol.barchart.com/getHistory.csv?apikey=958bd129b997922724b5242bdcc8cf9d&symbol=IBM&type=minutes&startDate=20200101&endDate=20200201&interval=60&order=asc&sessionFilter=EFK&splits=true÷nds=true&volume=sum&nearby=1&jerq=true"

myobj = {
    'apikey':'958bd129b997922724b5242bdcc8cf9d',
}

x = requests.post(urlPost, data = myobj)

f = open("dataset2.csv", "w")
f.write(x.text)
f.close()

# %%
urlPost = "https://marketdata.websol.barchart.com/getHistory.csv"

# %%
dataframe = pd.read_csv("dataset.csv")

# %%
dataframe[0:5]
# Out:
#   symbol         timestamp  tradingDay    open    high      low    close  \
# 0   GOOG  11/05/2020 11:45  11/05/2020   13996   13996   139829  1399037
# 1   GOOG  11/05/2020 11:50  11/05/2020  139892  139939  1398323   139879
# 2   GOOG  11/05/2020 11:55  11/05/2020  139891  139952   139846   139952
# 3   GOOG  11/05/2020 12:00  11/05/2020  139906  139967     1399   139909
# 4   GOOG  11/05/2020 12:05  11/05/2020  139943  139977    13981    13981
#
#    volume
# 0    7567
# 1    3968
# 2    4819
# 3    5142
# 4   11500

# %%
dataframe.describe()
# Out:
#                open          high           low         close         volume
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000
# mean   4.396000e+05  3.608101e+05  3.566961e+05  5.028537e+05   11668.873000
# std    5.532629e+05  5.040311e+05  5.006725e+05  5.851585e+05   16413.958367
# min    1.335000e+03  1.336000e+03  1.339000e+03  1.330000e+03    1885.000000
# 25%    1.371145e+05  1.358150e+05  1.349555e+05  1.375618e+05    5846.000000
# 50%    1.403570e+05  1.403150e+05  1.399490e+05  1.405410e+05    8026.000000
# 75%    4.398490e+05  1.429055e+05  1.426028e+05  1.357773e+06   11364.000000
# max    1.440096e+06  1.440005e+06  1.438216e+06  1.439565e+06  251891.000000

# %%
dataframe['timestamp'] = pd.to_datetime(dataframe["timestamp"], dayfirst=True)

# %%
plt.figure(figsize = (15,10))
plt.plot(dataframe['close'])
plt.show()
plt.close()

plt.figure(figsize = (15,10))
plt.plot(dataframe['timestamp'], dataframe['close'])
plt.show()
plt.close()

# %%
dataframe = dataframe.drop(["tradingDay"], axis=1)

dataframe['symbol'] = pd.factorize(dataframe['symbol'])[0] + 1

# %%
dataframe[0:5]
# Out:
#    symbol           timestamp    open    high      low    close  volume
# 0       1 2020-05-11 11:45:00   13996   13996   139829  1399037    7567
# 1       1 2020-05-11 11:50:00  139892  139939  1398323   139879    3968
# 2       1 2020-05-11 11:55:00  139891  139952   139846   139952    4819
# 3       1 2020-05-11 12:00:00  139906  139967     1399   139909    5142
# 4       1 2020-05-11 12:05:00  139943  139977    13981    13981   11500

# %%
dataframe.describe()
# Out:
#        symbol          open          high           low         close  \
# count  1000.0  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean      1.0  4.396000e+05  3.608101e+05  3.566961e+05  5.028537e+05
# std       0.0  5.532629e+05  5.040311e+05  5.006725e+05  5.851585e+05
# min       1.0  1.335000e+03  1.336000e+03  1.339000e+03  1.330000e+03
# 25%       1.0  1.371145e+05  1.358150e+05  1.349555e+05  1.375618e+05
# 50%       1.0  1.403570e+05  1.403150e+05  1.399490e+05  1.405410e+05
# 75%       1.0  4.398490e+05  1.429055e+05  1.426028e+05  1.357773e+06
# max       1.0  1.440096e+06  1.440005e+06  1.438216e+06  1.439565e+06
#
#               volume
# count    1000.000000
# mean    11668.873000
# std     16413.958367
# min      1885.000000
# 25%      5846.000000
# 50%      8026.000000
# 75%     11364.000000
# max    251891.000000

# %%
dataframe['close'].plot(kind="hist")

# %%
dataframe = dataframe[dataframe['close'] > 150000]

# %%
plt.figure(figsize = (15,10))
plt.plot(dataframe['timestamp'],dataframe['close'], label='GOOG')

plt.legend(loc='best')
plt.show()
plt.close()

# %%
look_back = 5
forward_days = 5
num_periods = 20
lstmPrimeiraLayer = 64
lstmSegundaLayer = 32

nEpocas = 100
steps_per_epoch = 20
VALIDATION_SIZE = 1
BATCH_SIZE = 16
checkpoint = "bestLstmModel.hdf5"

# %%
X = dataframe.drop(["close"], axis=1)
y = dataframe["close"]


array = dataframe["close"].values.reshape(dataframe["close"].shape[0],1)


scl = MinMaxScaler()
array = scl.fit_transform(array)
division = len(array) - num_periods*forward_days

array_test = array[division-look_back:]
array_train = array[:division]

# %%
def processData(data, look_back, forward_days,jump=1):
    X,Y = [],[]
    for i in range(0,len(data) -look_back -forward_days +1, jump):
        X.append(data[i:(i+look_back)])
        Y.append(data[(i+look_back):(i+look_back+forward_days)])
    return np.array(X),np.array(Y)


_test,y_test = processData(array_test,look_back,forward_days,forward_days)
y_test = np.array([list(a.ravel()) for a in y_test])

X,y = processData(array_train,look_back,forward_days)
y = np.array([list(a.ravel()) for a in y])


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model = Sequential()

model.add(LSTM(units=lstmPrimeiraLayer, input_shape=(look_back,1), return_sequences=True))

model.add(LSTM(units=lstmSegundaLayer,input_shape=(lstmPrimeiraLayer,1)))

model.add(Dense(units=forward_days, activation='linear'))

model.compile(loss='mean_absolute_error', optimizer='adam', metrics = ['mse', 'mae', 'mape', 'cosine'])

mc = ModelCheckpoint(checkpoint, monitor='loss', verbose=1, save_best_only=True, mode='min')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100, min_delta=0.000001)

# fit the model
compute_steps_per_epoch = lambda x: int(math.ceil(1. * x / BATCH_SIZE))
val_steps = compute_steps_per_epoch(VALIDATION_SIZE)

#batch_size = numero de execuções antes de atualizar os erros.
history = model.fit( X_train, y_train, epochs=nEpocas, steps_per_epoch=steps_per_epoch, callbacks=[es, mc], validation_steps = val_steps, validation_data=(X_test, y_test))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0530 15:38:07.526743 16900 deprecation_wrapper.py:119] From c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0530 15:38:08.154907 16900 deprecation_wrapper.py:119] From c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0530 15:38:08.308111 16900 deprecation_wrapper.py:119] From c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0530 15:38:08.749737 16900 deprecation_wrapper.py:119] From c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0530 15:38:09.225954 16900 deprecation.py:323] From c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0530 15:38:09.868981 16900 deprecation_wrapper.py:119] From c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0530 15:38:09.926986 16900 deprecation_wrapper.py:119] From c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 128 samples, validate on 64 samples
# Epoch 1/100
# 20/20 [==============================] - 13s 673ms/step - loss: 0.3671 - mean_squared_error: 0.1804 - mean_absolute_error: 0.3671 - mean_absolute_percentage_error: 74.0447 - cosine_proximity: -0.8348 - val_loss: 0.2201 - val_mean_squared_error: 0.0623 - val_mean_absolute_error: 0.2201 - val_mean_absolute_percentage_error: 2677349.5000 - val_cosine_proximity: -0.9796
#
# Epoch 00001: loss improved from inf to 0.36714, saving model to bestLstmModel.hdf5
# Epoch 2/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.1232 - mean_squared_error: 0.0235 - mean_absolute_error: 0.1232 - mean_absolute_percentage_error: 48.6601 - cosine_proximity: -0.9918 - val_loss: 0.1004 - val_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.1004 - val_mean_absolute_percentage_error: 3965953.0000 - val_cosine_proximity: -0.9834
#
# Epoch 00002: loss improved from 0.36714 to 0.12316, saving model to bestLstmModel.hdf5
# Epoch 3/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0802 - mean_squared_error: 0.0109 - mean_absolute_error: 0.0802 - mean_absolute_percentage_error: 38.2304 - cosine_proximity: -0.9935 - val_loss: 0.0701 - val_mean_squared_error: 0.0083 - val_mean_absolute_error: 0.0701 - val_mean_absolute_percentage_error: 3425006.7500 - val_cosine_proximity: -0.9840
#
# Epoch 00003: loss improved from 0.12316 to 0.08024, saving model to bestLstmModel.hdf5
# Epoch 4/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0572 - mean_squared_error: 0.0067 - mean_absolute_error: 0.0572 - mean_absolute_percentage_error: 25.1189 - cosine_proximity: -0.9937 - val_loss: 0.0637 - val_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0637 - val_mean_absolute_percentage_error: 2222478.5000 - val_cosine_proximity: -0.9840
#
# Epoch 00004: loss improved from 0.08024 to 0.05718, saving model to bestLstmModel.hdf5
# Epoch 5/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0505 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0505 - mean_absolute_percentage_error: 18.2516 - cosine_proximity: -0.9939 - val_loss: 0.0644 - val_mean_squared_error: 0.0074 - val_mean_absolute_error: 0.0644 - val_mean_absolute_percentage_error: 2007080.1250 - val_cosine_proximity: -0.9840
#
# Epoch 00005: loss improved from 0.05718 to 0.05048, saving model to bestLstmModel.hdf5
# Epoch 6/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0499 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0499 - mean_absolute_percentage_error: 18.5742 - cosine_proximity: -0.9941 - val_loss: 0.0632 - val_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0632 - val_mean_absolute_percentage_error: 2170995.5000 - val_cosine_proximity: -0.9840
#
# Epoch 00006: loss improved from 0.05048 to 0.04995, saving model to bestLstmModel.hdf5
# Epoch 7/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0498 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0498 - mean_absolute_percentage_error: 18.5541 - cosine_proximity: -0.9941 - val_loss: 0.0633 - val_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0633 - val_mean_absolute_percentage_error: 2106803.0000 - val_cosine_proximity: -0.9839
#
# Epoch 00007: loss improved from 0.04995 to 0.04977, saving model to bestLstmModel.hdf5
# Epoch 8/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0496 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0496 - mean_absolute_percentage_error: 18.4103 - cosine_proximity: -0.9942 - val_loss: 0.0629 - val_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0629 - val_mean_absolute_percentage_error: 2107019.5000 - val_cosine_proximity: -0.9839
#
# Epoch 00008: loss improved from 0.04977 to 0.04963, saving model to bestLstmModel.hdf5
# Epoch 9/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0495 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0495 - mean_absolute_percentage_error: 18.3382 - cosine_proximity: -0.9942 - val_loss: 0.0626 - val_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0626 - val_mean_absolute_percentage_error: 2099362.2500 - val_cosine_proximity: -0.9839
#
# Epoch 00009: loss improved from 0.04963 to 0.04948, saving model to bestLstmModel.hdf5
# Epoch 10/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0493 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0493 - mean_absolute_percentage_error: 18.3030 - cosine_proximity: -0.9942 - val_loss: 0.0623 - val_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0623 - val_mean_absolute_percentage_error: 2102383.7500 - val_cosine_proximity: -0.9838
#
# Epoch 00010: loss improved from 0.04948 to 0.04933, saving model to bestLstmModel.hdf5
# Epoch 11/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0492 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0492 - mean_absolute_percentage_error: 18.2725 - cosine_proximity: -0.9942 - val_loss: 0.0620 - val_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0620 - val_mean_absolute_percentage_error: 2102007.2500 - val_cosine_proximity: -0.9838
#
# Epoch 00011: loss improved from 0.04933 to 0.04916, saving model to bestLstmModel.hdf5
# Epoch 12/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0490 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0490 - mean_absolute_percentage_error: 18.2342 - cosine_proximity: -0.9942 - val_loss: 0.0617 - val_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0617 - val_mean_absolute_percentage_error: 2103586.2500 - val_cosine_proximity: -0.9837
#
# Epoch 00012: loss improved from 0.04916 to 0.04898, saving model to bestLstmModel.hdf5
# Epoch 13/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0488 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0488 - mean_absolute_percentage_error: 18.1933 - cosine_proximity: -0.9942 - val_loss: 0.0613 - val_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0613 - val_mean_absolute_percentage_error: 2101070.7500 - val_cosine_proximity: -0.9837
#
# Epoch 00013: loss improved from 0.04898 to 0.04879, saving model to bestLstmModel.hdf5
# Epoch 14/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0486 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0486 - mean_absolute_percentage_error: 18.1315 - cosine_proximity: -0.9942 - val_loss: 0.0609 - val_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0609 - val_mean_absolute_percentage_error: 2102209.7500 - val_cosine_proximity: -0.9837
#
# Epoch 00014: loss improved from 0.04879 to 0.04856, saving model to bestLstmModel.hdf5
# Epoch 15/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0483 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0483 - mean_absolute_percentage_error: 18.0538 - cosine_proximity: -0.9941 - val_loss: 0.0604 - val_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0604 - val_mean_absolute_percentage_error: 2095129.2500 - val_cosine_proximity: -0.9837
#
# Epoch 00015: loss improved from 0.04856 to 0.04830, saving model to bestLstmModel.hdf5
# Epoch 16/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0480 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0480 - mean_absolute_percentage_error: 17.9542 - cosine_proximity: -0.9941 - val_loss: 0.0599 - val_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0599 - val_mean_absolute_percentage_error: 2085407.1250 - val_cosine_proximity: -0.9837
#
# Epoch 00016: loss improved from 0.04830 to 0.04801, saving model to bestLstmModel.hdf5
# Epoch 17/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0477 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0477 - mean_absolute_percentage_error: 17.8479 - cosine_proximity: -0.9941 - val_loss: 0.0591 - val_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0591 - val_mean_absolute_percentage_error: 2076476.7500 - val_cosine_proximity: -0.9837
#
# Epoch 00017: loss improved from 0.04801 to 0.04768, saving model to bestLstmModel.hdf5
# Epoch 18/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0473 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0473 - mean_absolute_percentage_error: 17.7307 - cosine_proximity: -0.9941 - val_loss: 0.0582 - val_mean_squared_error: 0.0063 - val_mean_absolute_error: 0.0582 - val_mean_absolute_percentage_error: 2081513.0000 - val_cosine_proximity: -0.9838
#
# Epoch 00018: loss improved from 0.04768 to 0.04729, saving model to bestLstmModel.hdf5
# Epoch 19/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0469 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0469 - mean_absolute_percentage_error: 17.5870 - cosine_proximity: -0.9941 - val_loss: 0.0574 - val_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0574 - val_mean_absolute_percentage_error: 2062451.8750 - val_cosine_proximity: -0.9838
#
# Epoch 00019: loss improved from 0.04729 to 0.04689, saving model to bestLstmModel.hdf5
# Epoch 20/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0464 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0464 - mean_absolute_percentage_error: 17.3962 - cosine_proximity: -0.9941 - val_loss: 0.0565 - val_mean_squared_error: 0.0060 - val_mean_absolute_error: 0.0565 - val_mean_absolute_percentage_error: 2038808.3750 - val_cosine_proximity: -0.9836
#
# Epoch 00020: loss improved from 0.04689 to 0.04643, saving model to bestLstmModel.hdf5
# Epoch 21/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0460 - mean_squared_error: 0.0049 - mean_absolute_error: 0.0460 - mean_absolute_percentage_error: 17.1933 - cosine_proximity: -0.9941 - val_loss: 0.0557 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0557 - val_mean_absolute_percentage_error: 2029241.3750 - val_cosine_proximity: -0.9836
#
# Epoch 00021: loss improved from 0.04643 to 0.04600, saving model to bestLstmModel.hdf5
# Epoch 22/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0455 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0455 - mean_absolute_percentage_error: 17.0063 - cosine_proximity: -0.9942 - val_loss: 0.0551 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0551 - val_mean_absolute_percentage_error: 2020469.3750 - val_cosine_proximity: -0.9835
#
# Epoch 00022: loss improved from 0.04600 to 0.04552, saving model to bestLstmModel.hdf5
# Epoch 23/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0451 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0451 - mean_absolute_percentage_error: 16.8308 - cosine_proximity: -0.9942 - val_loss: 0.0545 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0545 - val_mean_absolute_percentage_error: 2018290.5000 - val_cosine_proximity: -0.9835
#
# Epoch 00023: loss improved from 0.04552 to 0.04507, saving model to bestLstmModel.hdf5
# Epoch 24/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0446 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0446 - mean_absolute_percentage_error: 16.6490 - cosine_proximity: -0.9942 - val_loss: 0.0540 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0540 - val_mean_absolute_percentage_error: 2041617.3750 - val_cosine_proximity: -0.9835
#
# Epoch 00024: loss improved from 0.04507 to 0.04464, saving model to bestLstmModel.hdf5
# Epoch 25/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0442 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0442 - mean_absolute_percentage_error: 16.4729 - cosine_proximity: -0.9942 - val_loss: 0.0535 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0535 - val_mean_absolute_percentage_error: 2033280.7500 - val_cosine_proximity: -0.9834
#
# Epoch 00025: loss improved from 0.04464 to 0.04420, saving model to bestLstmModel.hdf5
# Epoch 26/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0439 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0439 - mean_absolute_percentage_error: 16.3201 - cosine_proximity: -0.9942 - val_loss: 0.0531 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0531 - val_mean_absolute_percentage_error: 2037583.6250 - val_cosine_proximity: -0.9834
#
# Epoch 00026: loss improved from 0.04420 to 0.04386, saving model to bestLstmModel.hdf5
# Epoch 27/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0435 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0435 - mean_absolute_percentage_error: 16.1367 - cosine_proximity: -0.9942 - val_loss: 0.0528 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0528 - val_mean_absolute_percentage_error: 2036902.0000 - val_cosine_proximity: -0.9833
#
# Epoch 00027: loss improved from 0.04386 to 0.04345, saving model to bestLstmModel.hdf5
# Epoch 28/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0431 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0431 - mean_absolute_percentage_error: 15.9589 - cosine_proximity: -0.9941 - val_loss: 0.0528 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0528 - val_mean_absolute_percentage_error: 2033038.6250 - val_cosine_proximity: -0.9833
#
# Epoch 00028: loss improved from 0.04345 to 0.04313, saving model to bestLstmModel.hdf5
# Epoch 29/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0432 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0432 - mean_absolute_percentage_error: 15.8641 - cosine_proximity: -0.9942 - val_loss: 0.0529 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0529 - val_mean_absolute_percentage_error: 2017265.6250 - val_cosine_proximity: -0.9832
#
# Epoch 00029: loss did not improve from 0.04313
# Epoch 30/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0425 - mean_squared_error: 0.0041 - mean_absolute_error: 0.0425 - mean_absolute_percentage_error: 15.6412 - cosine_proximity: -0.9942 - val_loss: 0.0529 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0529 - val_mean_absolute_percentage_error: 2028042.5000 - val_cosine_proximity: -0.9832
#
# Epoch 00030: loss improved from 0.04313 to 0.04249, saving model to bestLstmModel.hdf5
# Epoch 31/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0422 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0422 - mean_absolute_percentage_error: 15.4868 - cosine_proximity: -0.9942 - val_loss: 0.0531 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0531 - val_mean_absolute_percentage_error: 2031749.2500 - val_cosine_proximity: -0.9832
#
# Epoch 00031: loss improved from 0.04249 to 0.04217, saving model to bestLstmModel.hdf5
# Epoch 32/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0419 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0419 - mean_absolute_percentage_error: 15.3509 - cosine_proximity: -0.9942 - val_loss: 0.0533 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0533 - val_mean_absolute_percentage_error: 2012365.1250 - val_cosine_proximity: -0.9831
#
# Epoch 00032: loss improved from 0.04217 to 0.04187, saving model to bestLstmModel.hdf5
# Epoch 33/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0419 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0419 - mean_absolute_percentage_error: 15.2526 - cosine_proximity: -0.9942 - val_loss: 0.0535 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0535 - val_mean_absolute_percentage_error: 2036703.1250 - val_cosine_proximity: -0.9830
#
# Epoch 00033: loss improved from 0.04187 to 0.04186, saving model to bestLstmModel.hdf5
# Epoch 34/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0415 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0415 - mean_absolute_percentage_error: 15.1367 - cosine_proximity: -0.9942 - val_loss: 0.0534 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0534 - val_mean_absolute_percentage_error: 2016316.0000 - val_cosine_proximity: -0.9831
#
# Epoch 00034: loss improved from 0.04186 to 0.04154, saving model to bestLstmModel.hdf5
# Epoch 35/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0412 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0412 - mean_absolute_percentage_error: 14.9944 - cosine_proximity: -0.9942 - val_loss: 0.0535 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0535 - val_mean_absolute_percentage_error: 2029619.3750 - val_cosine_proximity: -0.9831
# Epoch 00035: loss improved from 0.04154 to 0.04116, saving model to bestLstmModel.hdf5
# Epoch 36/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0409 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0409 - mean_absolute_percentage_error: 14.8728 - cosine_proximity: -0.9942 - val_loss: 0.0537 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0537 - val_mean_absolute_percentage_error: 2015587.0000 - val_cosine_proximity: -0.9831
#
# Epoch 00036: loss improved from 0.04116 to 0.04092, saving model to bestLstmModel.hdf5
# Epoch 37/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0410 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0410 - mean_absolute_percentage_error: 14.8024 - cosine_proximity: -0.9942 - val_loss: 0.0538 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0538 - val_mean_absolute_percentage_error: 2045436.5000 - val_cosine_proximity: -0.9830
#
# Epoch 00037: loss did not improve from 0.04092
# Epoch 38/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0409 - mean_squared_error: 0.0038 - mean_absolute_error: 0.0409 - mean_absolute_percentage_error: 14.7502 - cosine_proximity: -0.9942 - val_loss: 0.0543 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0543 - val_mean_absolute_percentage_error: 2013353.8750 - val_cosine_proximity: -0.9829
#
# Epoch 00038: loss did not improve from 0.04092
# Epoch 39/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0405 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0405 - mean_absolute_percentage_error: 14.6143 - cosine_proximity: -0.9942 - val_loss: 0.0540 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0540 - val_mean_absolute_percentage_error: 2035021.7500 - val_cosine_proximity: -0.9829
#
# Epoch 00039: loss improved from 0.04092 to 0.04046, saving model to bestLstmModel.hdf5
# Epoch 40/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0403 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0403 - mean_absolute_percentage_error: 14.5474 - cosine_proximity: -0.9942 - val_loss: 0.0539 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0539 - val_mean_absolute_percentage_error: 2036526.5000 - val_cosine_proximity: -0.9830
#
# Epoch 00040: loss improved from 0.04046 to 0.04034, saving model to bestLstmModel.hdf5
# Epoch 41/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0402 - mean_squared_error: 0.0037 - mean_absolute_error: 0.0402 - mean_absolute_percentage_error: 14.4757 - cosine_proximity: -0.9942 - val_loss: 0.0540 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0540 - val_mean_absolute_percentage_error: 2043411.6250 - val_cosine_proximity: -0.9828
#
# Epoch 00041: loss improved from 0.04034 to 0.04023, saving model to bestLstmModel.hdf5
# Epoch 42/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0399 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0399 - mean_absolute_percentage_error: 14.4015 - cosine_proximity: -0.9942 - val_loss: 0.0542 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0542 - val_mean_absolute_percentage_error: 2016004.3750 - val_cosine_proximity: -0.9829
#
# Epoch 00042: loss improved from 0.04023 to 0.03995, saving model to bestLstmModel.hdf5
# Epoch 43/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0400 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0400 - mean_absolute_percentage_error: 14.3405 - cosine_proximity: -0.9943 - val_loss: 0.0549 - val_mean_squared_error: 0.0056 - val_mean_absolute_error: 0.0549 - val_mean_absolute_percentage_error: 1998507.5000 - val_cosine_proximity: -0.9830
#
# Epoch 00043: loss did not improve from 0.03995
# Epoch 44/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0399 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0399 - mean_absolute_percentage_error: 14.3100 - cosine_proximity: -0.9943 - val_loss: 0.0541 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0541 - val_mean_absolute_percentage_error: 2015595.5000 - val_cosine_proximity: -0.9830
#
# Epoch 00044: loss improved from 0.03995 to 0.03987, saving model to bestLstmModel.hdf5
# Epoch 45/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0393 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0393 - mean_absolute_percentage_error: 14.1768 - cosine_proximity: -0.9943 - val_loss: 0.0537 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0537 - val_mean_absolute_percentage_error: 2027867.8750 - val_cosine_proximity: -0.9830
#
# Epoch 00045: loss improved from 0.03987 to 0.03934, saving model to bestLstmModel.hdf5
# Epoch 46/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0393 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0393 - mean_absolute_percentage_error: 14.1532 - cosine_proximity: -0.9943 - val_loss: 0.0537 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0537 - val_mean_absolute_percentage_error: 2031837.8750 - val_cosine_proximity: -0.9831
#
# Epoch 00046: loss did not improve from 0.03934
# Epoch 47/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0391 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0391 - mean_absolute_percentage_error: 14.0793 - cosine_proximity: -0.9943 - val_loss: 0.0535 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0535 - val_mean_absolute_percentage_error: 2036962.7500 - val_cosine_proximity: -0.9831
#
# Epoch 00047: loss improved from 0.03934 to 0.03908, saving model to bestLstmModel.hdf5
# Epoch 48/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0389 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0389 - mean_absolute_percentage_error: 14.0188 - cosine_proximity: -0.9943 - val_loss: 0.0537 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0537 - val_mean_absolute_percentage_error: 2026899.0000 - val_cosine_proximity: -0.9831
#
# Epoch 00048: loss improved from 0.03908 to 0.03888, saving model to bestLstmModel.hdf5
# Epoch 49/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0389 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0389 - mean_absolute_percentage_error: 13.9960 - cosine_proximity: -0.9943 - val_loss: 0.0537 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0537 - val_mean_absolute_percentage_error: 2021074.0000 - val_cosine_proximity: -0.9830
#
# Epoch 00049: loss did not improve from 0.03888
# Epoch 50/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0388 - mean_squared_error: 0.0035 - mean_absolute_error: 0.0388 - mean_absolute_percentage_error: 13.9419 - cosine_proximity: -0.9944 - val_loss: 0.0533 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0533 - val_mean_absolute_percentage_error: 2030984.1250 - val_cosine_proximity: -0.9831
#
# Epoch 00050: loss improved from 0.03888 to 0.03876, saving model to bestLstmModel.hdf5
# Epoch 51/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0385 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0385 - mean_absolute_percentage_error: 13.8750 - cosine_proximity: -0.9944 - val_loss: 0.0532 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0532 - val_mean_absolute_percentage_error: 2069210.5000 - val_cosine_proximity: -0.9832
#
# Epoch 00051: loss improved from 0.03876 to 0.03854, saving model to bestLstmModel.hdf5
# Epoch 52/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0385 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0385 - mean_absolute_percentage_error: 13.8567 - cosine_proximity: -0.9944 - val_loss: 0.0530 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0530 - val_mean_absolute_percentage_error: 2049386.3750 - val_cosine_proximity: -0.9831
#
# Epoch 00052: loss did not improve from 0.03854
# Epoch 53/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0383 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0383 - mean_absolute_percentage_error: 13.7836 - cosine_proximity: -0.9944 - val_loss: 0.0528 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0528 - val_mean_absolute_percentage_error: 2042414.3750 - val_cosine_proximity: -0.9831
#
# Epoch 00053: loss improved from 0.03854 to 0.03827, saving model to bestLstmModel.hdf5
# Epoch 54/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0382 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0382 - mean_absolute_percentage_error: 13.7446 - cosine_proximity: -0.9944 - val_loss: 0.0528 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0528 - val_mean_absolute_percentage_error: 2065212.7500 - val_cosine_proximity: -0.9832
#
# Epoch 00054: loss improved from 0.03827 to 0.03824, saving model to bestLstmModel.hdf5
# Epoch 55/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0383 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0383 - mean_absolute_percentage_error: 13.7529 - cosine_proximity: -0.9944 - val_loss: 0.0527 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0527 - val_mean_absolute_percentage_error: 2027535.8750 - val_cosine_proximity: -0.9831
#
# Epoch 00055: loss did not improve from 0.03824
# Epoch 56/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0380 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0380 - mean_absolute_percentage_error: 13.6592 - cosine_proximity: -0.9944 - val_loss: 0.0524 - val_mean_squared_error: 0.0054 - val_mean_absolute_error: 0.0524 - val_mean_absolute_percentage_error: 2051302.5000 - val_cosine_proximity: -0.9831
#
# Epoch 00056: loss improved from 0.03824 to 0.03800, saving model to bestLstmModel.hdf5
# Epoch 57/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0380 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0380 - mean_absolute_percentage_error: 13.6408 - cosine_proximity: -0.9945 - val_loss: 0.0523 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0523 - val_mean_absolute_percentage_error: 2061476.0000 - val_cosine_proximity: -0.9832
#
# Epoch 00057: loss improved from 0.03800 to 0.03798, saving model to bestLstmModel.hdf5
# Epoch 58/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0381 - mean_squared_error: 0.0034 - mean_absolute_error: 0.0381 - mean_absolute_percentage_error: 13.6543 - cosine_proximity: -0.9945 - val_loss: 0.0537 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0537 - val_mean_absolute_percentage_error: 1999310.7500 - val_cosine_proximity: -0.9829
#
# Epoch 00058: loss did not improve from 0.03798
# Epoch 59/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0380 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0380 - mean_absolute_percentage_error: 13.6127 - cosine_proximity: -0.9945 - val_loss: 0.0521 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0521 - val_mean_absolute_percentage_error: 2043659.0000 - val_cosine_proximity: -0.9832
#
# Epoch 00059: loss improved from 0.03798 to 0.03797, saving model to bestLstmModel.hdf5
# Epoch 60/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0376 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0376 - mean_absolute_percentage_error: 13.5186 - cosine_proximity: -0.9945 - val_loss: 0.0520 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0520 - val_mean_absolute_percentage_error: 2034093.5000 - val_cosine_proximity: -0.9832
#
# Epoch 00060: loss improved from 0.03797 to 0.03757, saving model to bestLstmModel.hdf5
# Epoch 61/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0376 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0376 - mean_absolute_percentage_error: 13.4942 - cosine_proximity: -0.9945 - val_loss: 0.0522 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0522 - val_mean_absolute_percentage_error: 2025338.2500 - val_cosine_proximity: -0.9832
#
# Epoch 00061: loss did not improve from 0.03757
# Epoch 62/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0379 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0379 - mean_absolute_percentage_error: 13.5189 - cosine_proximity: -0.9945 - val_loss: 0.0519 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0519 - val_mean_absolute_percentage_error: 2060074.2500 - val_cosine_proximity: -0.9832
#
# Epoch 00062: loss did not improve from 0.03757
# Epoch 63/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0373 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0373 - mean_absolute_percentage_error: 13.4227 - cosine_proximity: -0.9945 - val_loss: 0.0517 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0517 - val_mean_absolute_percentage_error: 2046046.6250 - val_cosine_proximity: -0.9833
#
# Epoch 00063: loss improved from 0.03757 to 0.03733, saving model to bestLstmModel.hdf5
# Epoch 64/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0378 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0378 - mean_absolute_percentage_error: 13.4751 - cosine_proximity: -0.9945 - val_loss: 0.0540 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0540 - val_mean_absolute_percentage_error: 1982754.0000 - val_cosine_proximity: -0.9829
#
# Epoch 00064: loss did not improve from 0.03733
# Epoch 65/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0385 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0385 - mean_absolute_percentage_error: 13.6039 - cosine_proximity: -0.9945 - val_loss: 0.0520 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0520 - val_mean_absolute_percentage_error: 2106476.5000 - val_cosine_proximity: -0.9833
#
# Epoch 00065: loss did not improve from 0.03733
# Epoch 66/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0374 - mean_squared_error: 0.0033 - mean_absolute_error: 0.0374 - mean_absolute_percentage_error: 13.4234 - cosine_proximity: -0.9945 - val_loss: 0.0515 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0515 - val_mean_absolute_percentage_error: 2044782.6250 - val_cosine_proximity: -0.9834
#
# Epoch 00066: loss did not improve from 0.03733
# Epoch 67/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0371 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0371 - mean_absolute_percentage_error: 13.3341 - cosine_proximity: -0.9945 - val_loss: 0.0513 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0513 - val_mean_absolute_percentage_error: 2051636.8750 - val_cosine_proximity: -0.9834
#
# Epoch 00067: loss improved from 0.03733 to 0.03711, saving model to bestLstmModel.hdf5
# Epoch 68/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0370 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0370 - mean_absolute_percentage_error: 13.2996 - cosine_proximity: -0.9946 - val_loss: 0.0513 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0513 - val_mean_absolute_percentage_error: 2047488.8750 - val_cosine_proximity: -0.9834
#
# Epoch 00068: loss improved from 0.03711 to 0.03702, saving model to bestLstmModel.hdf5
# Epoch 69/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0369 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0369 - mean_absolute_percentage_error: 13.2653 - cosine_proximity: -0.9946 - val_loss: 0.0513 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0513 - val_mean_absolute_percentage_error: 2043338.1250 - val_cosine_proximity: -0.9834
#
# Epoch 00069: loss improved from 0.03702 to 0.03695, saving model to bestLstmModel.hdf5
# Epoch 70/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0372 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0372 - mean_absolute_percentage_error: 13.2888 - cosine_proximity: -0.9945 - val_loss: 0.0512 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0512 - val_mean_absolute_percentage_error: 2065942.0000 - val_cosine_proximity: -0.9833
#
# Epoch 00070: loss did not improve from 0.03695
# Epoch 71/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0373 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0373 - mean_absolute_percentage_error: 13.2982 - cosine_proximity: -0.9945 - val_loss: 0.0511 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0511 - val_mean_absolute_percentage_error: 2036155.6250 - val_cosine_proximity: -0.9834
#
# Epoch 00071: loss did not improve from 0.03695
# Epoch 72/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0369 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0369 - mean_absolute_percentage_error: 13.2227 - cosine_proximity: -0.9945 - val_loss: 0.0512 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0512 - val_mean_absolute_percentage_error: 2044483.8750 - val_cosine_proximity: -0.9834
#
# Epoch 00072: loss improved from 0.03695 to 0.03692, saving model to bestLstmModel.hdf5
# Epoch 73/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0369 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0369 - mean_absolute_percentage_error: 13.2139 - cosine_proximity: -0.9946 - val_loss: 0.0511 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0511 - val_mean_absolute_percentage_error: 2067073.0000 - val_cosine_proximity: -0.9834
#
# Epoch 00073: loss did not improve from 0.03692
# Epoch 74/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0368 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0368 - mean_absolute_percentage_error: 13.1755 - cosine_proximity: -0.9946 - val_loss: 0.0511 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0511 - val_mean_absolute_percentage_error: 2074610.3750 - val_cosine_proximity: -0.9835
#
# Epoch 00074: loss improved from 0.03692 to 0.03681, saving model to bestLstmModel.hdf5
# Epoch 75/100
# 20/20 [==============================] - 0s 17ms/step - loss: 0.0370 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0370 - mean_absolute_percentage_error: 13.1951 - cosine_proximity: -0.9945 - val_loss: 0.0510 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0510 - val_mean_absolute_percentage_error: 2057029.6250 - val_cosine_proximity: -0.9835
#
# Epoch 00075: loss did not improve from 0.03681
# Epoch 76/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0367 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0367 - mean_absolute_percentage_error: 13.1564 - cosine_proximity: -0.9945 - val_loss: 0.0510 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0510 - val_mean_absolute_percentage_error: 2032822.0000 - val_cosine_proximity: -0.9834
#
# Epoch 00076: loss improved from 0.03681 to 0.03669, saving model to bestLstmModel.hdf5
# Epoch 77/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0367 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0367 - mean_absolute_percentage_error: 13.1487 - cosine_proximity: -0.9945 - val_loss: 0.0512 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0512 - val_mean_absolute_percentage_error: 2020915.2500 - val_cosine_proximity: -0.9834
#
# Epoch 00077: loss improved from 0.03669 to 0.03667, saving model to bestLstmModel.hdf5
# Epoch 78/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0370 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0370 - mean_absolute_percentage_error: 13.1738 - cosine_proximity: -0.9945 - val_loss: 0.0507 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0507 - val_mean_absolute_percentage_error: 2049593.8750 - val_cosine_proximity: -0.9835
#
# Epoch 00078: loss did not improve from 0.03667
# Epoch 79/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0369 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0369 - mean_absolute_percentage_error: 13.1692 - cosine_proximity: -0.9945 - val_loss: 0.0508 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0508 - val_mean_absolute_percentage_error: 2035605.5000 - val_cosine_proximity: -0.9835
#
# Epoch 00079: loss did not improve from 0.03667
# Epoch 80/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0367 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0367 - mean_absolute_percentage_error: 13.1285 - cosine_proximity: -0.9945 - val_loss: 0.0514 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0514 - val_mean_absolute_percentage_error: 2001070.6250 - val_cosine_proximity: -0.9835
#
# Epoch 00080: loss improved from 0.03667 to 0.03665, saving model to bestLstmModel.hdf5
# Epoch 81/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0368 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0368 - mean_absolute_percentage_error: 13.1410 - cosine_proximity: -0.9945 - val_loss: 0.0506 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0506 - val_mean_absolute_percentage_error: 2039491.7500 - val_cosine_proximity: -0.9835
#
# Epoch 00081: loss did not improve from 0.03665
# Epoch 82/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0366 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0366 - mean_absolute_percentage_error: 13.0970 - cosine_proximity: -0.9945 - val_loss: 0.0506 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0506 - val_mean_absolute_percentage_error: 2043306.7500 - val_cosine_proximity: -0.9835
#
# Epoch 00082: loss improved from 0.03665 to 0.03657, saving model to bestLstmModel.hdf5
# Epoch 83/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0365 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0365 - mean_absolute_percentage_error: 13.0813 - cosine_proximity: -0.9945 - val_loss: 0.0510 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0510 - val_mean_absolute_percentage_error: 2018906.2500 - val_cosine_proximity: -0.9834
#
# Epoch 00083: loss improved from 0.03657 to 0.03651, saving model to bestLstmModel.hdf5
# Epoch 84/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0365 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0365 - mean_absolute_percentage_error: 13.0833 - cosine_proximity: -0.9945 - val_loss: 0.0508 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0508 - val_mean_absolute_percentage_error: 2022472.5000 - val_cosine_proximity: -0.9834
#
# Epoch 00084: loss improved from 0.03651 to 0.03651, saving model to bestLstmModel.hdf5
# Epoch 85/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0364 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0364 - mean_absolute_percentage_error: 13.0532 - cosine_proximity: -0.9945 - val_loss: 0.0507 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0507 - val_mean_absolute_percentage_error: 2037438.5000 - val_cosine_proximity: -0.9834
#
# Epoch 00085: loss improved from 0.03651 to 0.03644, saving model to bestLstmModel.hdf5
# Epoch 86/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0365 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0365 - mean_absolute_percentage_error: 13.0720 - cosine_proximity: -0.9945 - val_loss: 0.0509 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0509 - val_mean_absolute_percentage_error: 2030475.0000 - val_cosine_proximity: -0.9834
#
# Epoch 00086: loss did not improve from 0.03644
# Epoch 87/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0365 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0365 - mean_absolute_percentage_error: 13.0549 - cosine_proximity: -0.9945 - val_loss: 0.0506 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0506 - val_mean_absolute_percentage_error: 2048666.3750 - val_cosine_proximity: -0.9834
#
# Epoch 00087: loss did not improve from 0.03644
# Epoch 88/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0365 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0365 - mean_absolute_percentage_error: 13.0612 - cosine_proximity: -0.9945 - val_loss: 0.0509 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0509 - val_mean_absolute_percentage_error: 2037978.0000 - val_cosine_proximity: -0.9833
#
# Epoch 00088: loss did not improve from 0.03644
# Epoch 89/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0366 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0366 - mean_absolute_percentage_error: 13.0784 - cosine_proximity: -0.9945 - val_loss: 0.0513 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0513 - val_mean_absolute_percentage_error: 2014772.6250 - val_cosine_proximity: -0.9834
#
# Epoch 00089: loss did not improve from 0.03644
# Epoch 90/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0365 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0365 - mean_absolute_percentage_error: 13.0354 - cosine_proximity: -0.9945 - val_loss: 0.0506 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0506 - val_mean_absolute_percentage_error: 2066225.5000 - val_cosine_proximity: -0.9835
#
# Epoch 00090: loss did not improve from 0.03644
# Epoch 91/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0364 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0364 - mean_absolute_percentage_error: 13.0343 - cosine_proximity: -0.9945 - val_loss: 0.0509 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0509 - val_mean_absolute_percentage_error: 2020639.3750 - val_cosine_proximity: -0.9834
#
# Epoch 00091: loss improved from 0.03644 to 0.03638, saving model to bestLstmModel.hdf5
# Epoch 92/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0365 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0365 - mean_absolute_percentage_error: 13.0298 - cosine_proximity: -0.9945 - val_loss: 0.0508 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0508 - val_mean_absolute_percentage_error: 2026726.3750 - val_cosine_proximity: -0.9834
#
# Epoch 00092: loss did not improve from 0.03638
# Epoch 93/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0364 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0364 - mean_absolute_percentage_error: 13.0146 - cosine_proximity: -0.9945 - val_loss: 0.0507 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0507 - val_mean_absolute_percentage_error: 2040156.7500 - val_cosine_proximity: -0.9834
#
# Epoch 00093: loss improved from 0.03638 to 0.03638, saving model to bestLstmModel.hdf5
# Epoch 94/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0364 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0364 - mean_absolute_percentage_error: 13.0142 - cosine_proximity: -0.9945 - val_loss: 0.0505 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0505 - val_mean_absolute_percentage_error: 2057335.6250 - val_cosine_proximity: -0.9834
#
# Epoch 00094: loss did not improve from 0.03638
# Epoch 95/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0364 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0364 - mean_absolute_percentage_error: 13.0178 - cosine_proximity: -0.9945 - val_loss: 0.0508 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0508 - val_mean_absolute_percentage_error: 2037621.2500 - val_cosine_proximity: -0.9834
#
# Epoch 00095: loss did not improve from 0.03638
# Epoch 96/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0363 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0363 - mean_absolute_percentage_error: 12.9836 - cosine_proximity: -0.9945 - val_loss: 0.0508 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0508 - val_mean_absolute_percentage_error: 2094198.1250 - val_cosine_proximity: -0.9835
#
# Epoch 00096: loss improved from 0.03638 to 0.03630, saving model to bestLstmModel.hdf5
# Epoch 97/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0364 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0364 - mean_absolute_percentage_error: 13.0126 - cosine_proximity: -0.9945 - val_loss: 0.0506 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0506 - val_mean_absolute_percentage_error: 2064750.5000 - val_cosine_proximity: -0.9835
#
# Epoch 00097: loss did not improve from 0.03630
# Epoch 98/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0364 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0364 - mean_absolute_percentage_error: 13.0281 - cosine_proximity: -0.9945 - val_loss: 0.0507 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0507 - val_mean_absolute_percentage_error: 2026278.2500 - val_cosine_proximity: -0.9834
#
# Epoch 00098: loss did not improve from 0.03630
# Epoch 99/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0363 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0363 - mean_absolute_percentage_error: 12.9650 - cosine_proximity: -0.9944 - val_loss: 0.0507 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0507 - val_mean_absolute_percentage_error: 2026922.3750 - val_cosine_proximity: -0.9835
#
# Epoch 00099: loss improved from 0.03630 to 0.03627, saving model to bestLstmModel.hdf5
# Epoch 100/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0363 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0363 - mean_absolute_percentage_error: 12.9609 - cosine_proximity: -0.9945 - val_loss: 0.0504 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0504 - val_mean_absolute_percentage_error: 2073937.7500 - val_cosine_proximity: -0.9835
#
# Epoch 00100: loss improved from 0.03627 to 0.03625, saving model to bestLstmModel.hdf5

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('mean_squared_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('mean_absolute_percentage_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['cosine_proximity'])
plt.plot(history.history['val_cosine_proximity'])
plt.title('cosine_proximity')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
Xt = model.predict(X_test)
plt.figure(figsize = (15,10))

for i in range(0,len(Xt)):
    plt.plot([x + i*forward_days for x in range(len(Xt[i]))], scl.inverse_transform(Xt[i].reshape(-1,1)), color='r')
    
plt.plot(0, scl.inverse_transform(Xt[i].reshape(-1,1))[0], color='r', label='Prediction') 
    
plt.plot(scl.inverse_transform(y_test.reshape(-1,1)), label='Target')
plt.legend(loc='best')
plt.show()

# %%
_data,y_data = processData(array,look_back,forward_days,forward_days)
Xt = model.predict(_data)

y = Xt.ravel()
division = len(array) - num_periods*forward_days

leftover = division%forward_days+1

# %%
plt.figure(figsize = (15,10))

# Data in Train/Validation
plt.plot([x for x in range(look_back+leftover, len(Xt)+look_back+leftover)], scl.inverse_transform(Xt.reshape(-1,1)), color='r', label='Train')
# Data in Test
plt.plot([x for x in range(look_back +leftover+ len(Xt), len(Xt))+look_back+leftover], scl.inverse_transform(Xtest.reshape(-1,1)), color='y', label='Test')

#Data used
plt.plot([x for x in range(look_back+leftover, look_back+leftover+len(Xt))], scl.inverse_transform(y.reshape(-1,1)), color='b', label='Target')

#Initial data. It should overlap the data used
#plt.plot(scl.inverse_transform(array), color='b', label='Esperado')

plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-232-451504c74775> in <module>
#       2
#       3 # Data in Train/Validation
# ----> 4 plt.plot([x for x in range(look_back+leftover, len(Xtrain)+look_back+leftover)], scl.inverse_transform(Xt.reshape(-1,1)), color='r', label='Train')
#       5 # Data in Test
#       6 plt.plot([x for x in range(look_back +leftover+ len(Xt), len(Xt))+look_back+leftover], scl.inverse_transform(Xtest.reshape(-1,1)), color='y', label='Test')
#
# NameError: name 'Xtrain' is not defined
