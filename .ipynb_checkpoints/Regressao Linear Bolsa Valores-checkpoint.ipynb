# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import math
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend as K
import matplotlib.dates as dates
from sklearn.preprocessing import MinMaxScaler
import requests

# %%
urlPost = "https://marketdata.websol.barchart.com/getHistory.csv?apikey=958bd129b997922724b5242bdcc8cf9d&symbol=IBM&type=minutes&startDate=20200101&endDate=20200201&interval=60&order=asc&sessionFilter=EFK&splits=true÷nds=true&volume=sum&nearby=1&jerq=true"

myobj = {
    'apikey':'958bd129b997922724b5242bdcc8cf9d',
}

x = requests.post(urlPost, data = myobj)

f = open("dataset2.csv", "w")
f.write(x.text)
f.close()

# %%
urlPost = "https://marketdata.websol.barchart.com/getHistory.csv"

# %%
dataframe = pd.read_csv("dataset.csv")

# %%
dataframe[0:5]
# Out:
#   symbol         timestamp  tradingDay    open    high      low    close  \
# 0   GOOG  11/05/2020 11:45  11/05/2020   13996   13996   139829  1399037
# 1   GOOG  11/05/2020 11:50  11/05/2020  139892  139939  1398323   139879
# 2   GOOG  11/05/2020 11:55  11/05/2020  139891  139952   139846   139952
# 3   GOOG  11/05/2020 12:00  11/05/2020  139906  139967     1399   139909
# 4   GOOG  11/05/2020 12:05  11/05/2020  139943  139977    13981    13981
#
#    volume
# 0    7567
# 1    3968
# 2    4819
# 3    5142
# 4   11500

# %%
dataframe.describe()
# Out:
#                open          high           low         close         volume
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000
# mean   4.396000e+05  3.608101e+05  3.566961e+05  5.028537e+05   11668.873000
# std    5.532629e+05  5.040311e+05  5.006725e+05  5.851585e+05   16413.958367
# min    1.335000e+03  1.336000e+03  1.339000e+03  1.330000e+03    1885.000000
# 25%    1.371145e+05  1.358150e+05  1.349555e+05  1.375618e+05    5846.000000
# 50%    1.403570e+05  1.403150e+05  1.399490e+05  1.405410e+05    8026.000000
# 75%    4.398490e+05  1.429055e+05  1.426028e+05  1.357773e+06   11364.000000
# max    1.440096e+06  1.440005e+06  1.438216e+06  1.439565e+06  251891.000000

# %%
dataframe['timestamp'] = pd.to_datetime(dataframe["timestamp"], dayfirst=True)

# %%
plt.figure(figsize = (15,10))
plt.plot(dataframe['close'])
plt.show()
plt.close()

plt.figure(figsize = (15,10))
plt.plot(dataframe['timestamp'], dataframe['close'])
plt.show()
plt.close()

# %%
dataframe = dataframe.drop(["tradingDay"], axis=1)

dataframe['symbol'] = pd.factorize(dataframe['symbol'])[0] + 1

# %%
dataframe[0:5]
# Out:
#    symbol           timestamp    open    high      low    close  volume
# 0       1 2020-05-11 11:45:00   13996   13996   139829  1399037    7567
# 1       1 2020-05-11 11:50:00  139892  139939  1398323   139879    3968
# 2       1 2020-05-11 11:55:00  139891  139952   139846   139952    4819
# 3       1 2020-05-11 12:00:00  139906  139967     1399   139909    5142
# 4       1 2020-05-11 12:05:00  139943  139977    13981    13981   11500

# %%
dataframe.describe()
# Out:
#        symbol          open          high           low         close  \
# count  1000.0  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean      1.0  4.396000e+05  3.608101e+05  3.566961e+05  5.028537e+05
# std       0.0  5.532629e+05  5.040311e+05  5.006725e+05  5.851585e+05
# min       1.0  1.335000e+03  1.336000e+03  1.339000e+03  1.330000e+03
# 25%       1.0  1.371145e+05  1.358150e+05  1.349555e+05  1.375618e+05
# 50%       1.0  1.403570e+05  1.403150e+05  1.399490e+05  1.405410e+05
# 75%       1.0  4.398490e+05  1.429055e+05  1.426028e+05  1.357773e+06
# max       1.0  1.440096e+06  1.440005e+06  1.438216e+06  1.439565e+06
#
#               volume
# count    1000.000000
# mean    11668.873000
# std     16413.958367
# min      1885.000000
# 25%      5846.000000
# 50%      8026.000000
# 75%     11364.000000
# max    251891.000000

# %%
dataframe['close'].plot(kind="hist")

# %%
dataframe = dataframe[dataframe['close'] > 150000]

# %%
plt.figure(figsize = (15,10))
plt.plot(dataframe['timestamp'],dataframe['close'], label='GOOG')

plt.legend(loc='best')
plt.show()
plt.close()

# %%
look_back = 3
forward_days = 3
num_periods = 20
lstmPrimeiraLayer = 64
lstmSegundaLayer = 32

nEpocas = 100
steps_per_epoch = 20
VALIDATION_SIZE = 1
BATCH_SIZE = 16
checkpoint = "bestLstmModel.hdf5"

# %%
X = dataframe.drop(["close"], axis=1)
y = dataframe["close"]


array = dataframe["close"].values.reshape(dataframe["close"].shape[0],1)


scl = MinMaxScaler()
array = scl.fit_transform(array)
division = len(array) - num_periods*forward_days

array_test = array[division-look_back:]
array_train = array[:division]

# %%
def processData(data, look_back, forward_days,jump=1):
    X,Y = [],[]
    for i in range(0,len(data) -look_back -forward_days +1, jump):
        X.append(data[i:(i+look_back)])
        Y.append(data[(i+look_back):(i+look_back+forward_days)])
    return np.array(X),np.array(Y)


_test,y_test = processData(array_test,look_back,forward_days,forward_days)
y_test = np.array([list(a.ravel()) for a in y_test])

X,y = processData(array_train,look_back,forward_days)
y = np.array([list(a.ravel()) for a in y])


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model = Sequential()

model.add(LSTM(units=lstmPrimeiraLayer, input_shape=(look_back,1), return_sequences=True))

model.add(LSTM(units=lstmSegundaLayer,input_shape=(lstmPrimeiraLayer,1)))

model.add(Dense(units=forward_days, activation='linear'))

model.compile(loss='mean_absolute_error', optimizer='adam', metrics = ['mse', 'mae', 'mape', 'cosine'])

mc = ModelCheckpoint(checkpoint, monitor='loss', verbose=1, save_best_only=True, mode='min')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100, min_delta=0.000001)

# fit the model
compute_steps_per_epoch = lambda x: int(math.ceil(1. * x / BATCH_SIZE))
val_steps = compute_steps_per_epoch(VALIDATION_SIZE)

#batch_size = numero de execuções antes de atualizar os erros.
history = model.fit( X_train, y_train, epochs=nEpocas, steps_per_epoch=steps_per_epoch, callbacks=[es, mc], validation_steps = val_steps, validation_data=(X_test, y_test))
# Out:
# Train on 99 samples, validate on 49 samples
# Epoch 1/100
# 20/20 [==============================] - 2s 94ms/step - loss: 0.2715 - mean_squared_error: 0.1135 - mean_absolute_error: 0.2715 - mean_absolute_percentage_error: 435284.4748 - cosine_proximity: -0.8392 - val_loss: 0.1565 - val_mean_squared_error: 0.0393 - val_mean_absolute_error: 0.1565 - val_mean_absolute_percentage_error: 2403404.0000 - val_cosine_proximity: -0.9271
#
# Epoch 00001: loss improved from inf to 0.27150, saving model to bestLstmModel.hdf5
# Epoch 2/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.1135 - mean_squared_error: 0.0212 - mean_absolute_error: 0.1135 - mean_absolute_percentage_error: 1331243.8375 - cosine_proximity: -0.9710 - val_loss: 0.0718 - val_mean_squared_error: 0.0106 - val_mean_absolute_error: 0.0718 - val_mean_absolute_percentage_error: 1790947.2500 - val_cosine_proximity: -0.9844
#
# Epoch 00002: loss improved from 0.27150 to 0.11351, saving model to bestLstmModel.hdf5
# Epoch 3/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0755 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0755 - mean_absolute_percentage_error: 1046353.9531 - cosine_proximity: -0.9838 - val_loss: 0.0567 - val_mean_squared_error: 0.0076 - val_mean_absolute_error: 0.0567 - val_mean_absolute_percentage_error: 1196804.1250 - val_cosine_proximity: -0.9866
#
# Epoch 00003: loss improved from 0.11351 to 0.07550, saving model to bestLstmModel.hdf5
# Epoch 4/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0713 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0713 - mean_absolute_percentage_error: 1002548.1219 - cosine_proximity: -0.9859 - val_loss: 0.0552 - val_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0552 - val_mean_absolute_percentage_error: 1352854.5000 - val_cosine_proximity: -0.9867
#
# Epoch 00004: loss improved from 0.07550 to 0.07130, saving model to bestLstmModel.hdf5
# Epoch 5/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0701 - mean_squared_error: 0.0106 - mean_absolute_error: 0.0701 - mean_absolute_percentage_error: 1007296.4781 - cosine_proximity: -0.9864 - val_loss: 0.0536 - val_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0536 - val_mean_absolute_percentage_error: 1264193.5000 - val_cosine_proximity: -0.9867
#
# Epoch 00005: loss improved from 0.07130 to 0.07012, saving model to bestLstmModel.hdf5
# Epoch 6/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0694 - mean_squared_error: 0.0105 - mean_absolute_error: 0.0694 - mean_absolute_percentage_error: 995708.9219 - cosine_proximity: -0.9864 - val_loss: 0.0530 - val_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0530 - val_mean_absolute_percentage_error: 1274158.6250 - val_cosine_proximity: -0.9867
#
# Epoch 00006: loss improved from 0.07012 to 0.06936, saving model to bestLstmModel.hdf5
# Epoch 7/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0686 - mean_squared_error: 0.0104 - mean_absolute_error: 0.0686 - mean_absolute_percentage_error: 995844.2750 - cosine_proximity: -0.9864 - val_loss: 0.0523 - val_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0523 - val_mean_absolute_percentage_error: 1269317.7500 - val_cosine_proximity: -0.9867
#
# Epoch 00007: loss improved from 0.06936 to 0.06864, saving model to bestLstmModel.hdf5
# Epoch 8/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0679 - mean_squared_error: 0.0102 - mean_absolute_error: 0.0679 - mean_absolute_percentage_error: 996399.3375 - cosine_proximity: -0.9864 - val_loss: 0.0516 - val_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0516 - val_mean_absolute_percentage_error: 1255087.0000 - val_cosine_proximity: -0.9867
#
# Epoch 00008: loss improved from 0.06864 to 0.06788, saving model to bestLstmModel.hdf5
# Epoch 9/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0670 - mean_squared_error: 0.0101 - mean_absolute_error: 0.0670 - mean_absolute_percentage_error: 997271.9906 - cosine_proximity: -0.9863 - val_loss: 0.0509 - val_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0509 - val_mean_absolute_percentage_error: 1241678.5000 - val_cosine_proximity: -0.9866
#
# Epoch 00009: loss improved from 0.06788 to 0.06702, saving model to bestLstmModel.hdf5
# Epoch 10/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0660 - mean_squared_error: 0.0099 - mean_absolute_error: 0.0660 - mean_absolute_percentage_error: 994776.4031 - cosine_proximity: -0.9863 - val_loss: 0.0501 - val_mean_squared_error: 0.0062 - val_mean_absolute_error: 0.0501 - val_mean_absolute_percentage_error: 1224826.2500 - val_cosine_proximity: -0.9866
#
# Epoch 00010: loss improved from 0.06702 to 0.06600, saving model to bestLstmModel.hdf5
# Epoch 11/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0648 - mean_squared_error: 0.0096 - mean_absolute_error: 0.0648 - mean_absolute_percentage_error: 980247.6094 - cosine_proximity: -0.9862 - val_loss: 0.0489 - val_mean_squared_error: 0.0059 - val_mean_absolute_error: 0.0489 - val_mean_absolute_percentage_error: 1189502.5000 - val_cosine_proximity: -0.9866
#
# Epoch 00011: loss improved from 0.06600 to 0.06477, saving model to bestLstmModel.hdf5
# Epoch 12/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0633 - mean_squared_error: 0.0091 - mean_absolute_error: 0.0633 - mean_absolute_percentage_error: 957557.5781 - cosine_proximity: -0.9861 - val_loss: 0.0478 - val_mean_squared_error: 0.0055 - val_mean_absolute_error: 0.0478 - val_mean_absolute_percentage_error: 1163811.3750 - val_cosine_proximity: -0.9866
#
# Epoch 00012: loss improved from 0.06477 to 0.06330, saving model to bestLstmModel.hdf5
# Epoch 13/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0618 - mean_squared_error: 0.0087 - mean_absolute_error: 0.0618 - mean_absolute_percentage_error: 938480.1938 - cosine_proximity: -0.9859 - val_loss: 0.0470 - val_mean_squared_error: 0.0052 - val_mean_absolute_error: 0.0470 - val_mean_absolute_percentage_error: 1146095.0000 - val_cosine_proximity: -0.9864
#
# Epoch 00013: loss improved from 0.06330 to 0.06178, saving model to bestLstmModel.hdf5
# Epoch 14/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0605 - mean_squared_error: 0.0081 - mean_absolute_error: 0.0605 - mean_absolute_percentage_error: 925402.4062 - cosine_proximity: -0.9858 - val_loss: 0.0471 - val_mean_squared_error: 0.0047 - val_mean_absolute_error: 0.0471 - val_mean_absolute_percentage_error: 1093184.1250 - val_cosine_proximity: -0.9862
#
# Epoch 00014: loss improved from 0.06178 to 0.06047, saving model to bestLstmModel.hdf5
# Epoch 15/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0591 - mean_squared_error: 0.0076 - mean_absolute_error: 0.0591 - mean_absolute_percentage_error: 921328.7781 - cosine_proximity: -0.9857 - val_loss: 0.0460 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0460 - val_mean_absolute_percentage_error: 1105128.6250 - val_cosine_proximity: -0.9862
#
# Epoch 00015: loss improved from 0.06047 to 0.05906, saving model to bestLstmModel.hdf5
# Epoch 16/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0578 - mean_squared_error: 0.0072 - mean_absolute_error: 0.0578 - mean_absolute_percentage_error: 911042.0500 - cosine_proximity: -0.9856 - val_loss: 0.0458 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 1054335.2500 - val_cosine_proximity: -0.9860
#
# Epoch 00016: loss improved from 0.05906 to 0.05782, saving model to bestLstmModel.hdf5
# Epoch 17/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0571 - mean_squared_error: 0.0069 - mean_absolute_error: 0.0571 - mean_absolute_percentage_error: 898469.5094 - cosine_proximity: -0.9855 - val_loss: 0.0460 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0460 - val_mean_absolute_percentage_error: 1066221.2500 - val_cosine_proximity: -0.9859
#
# Epoch 00017: loss improved from 0.05782 to 0.05706, saving model to bestLstmModel.hdf5
# Epoch 18/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0561 - mean_squared_error: 0.0066 - mean_absolute_error: 0.0561 - mean_absolute_percentage_error: 881024.2344 - cosine_proximity: -0.9857 - val_loss: 0.0462 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0462 - val_mean_absolute_percentage_error: 1060188.8750 - val_cosine_proximity: -0.9858
#
# Epoch 00018: loss improved from 0.05706 to 0.05611, saving model to bestLstmModel.hdf5
# Epoch 19/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0553 - mean_squared_error: 0.0064 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 872811.4125 - cosine_proximity: -0.9860 - val_loss: 0.0463 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0463 - val_mean_absolute_percentage_error: 1073276.3750 - val_cosine_proximity: -0.9860
#
# Epoch 00019: loss improved from 0.05611 to 0.05526, saving model to bestLstmModel.hdf5
# Epoch 20/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0548 - mean_squared_error: 0.0062 - mean_absolute_error: 0.0548 - mean_absolute_percentage_error: 869714.8281 - cosine_proximity: -0.9862 - val_loss: 0.0476 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0476 - val_mean_absolute_percentage_error: 1107944.0000 - val_cosine_proximity: -0.9860
#
# Epoch 00020: loss improved from 0.05526 to 0.05475, saving model to bestLstmModel.hdf5
# Epoch 21/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0543 - mean_squared_error: 0.0061 - mean_absolute_error: 0.0543 - mean_absolute_percentage_error: 870079.8719 - cosine_proximity: -0.9863 - val_loss: 0.0474 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0474 - val_mean_absolute_percentage_error: 1092196.1250 - val_cosine_proximity: -0.9861
#
# Epoch 00021: loss improved from 0.05475 to 0.05434, saving model to bestLstmModel.hdf5
# Epoch 22/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0538 - mean_squared_error: 0.0060 - mean_absolute_error: 0.0538 - mean_absolute_percentage_error: 864966.4594 - cosine_proximity: -0.9865 - val_loss: 0.0471 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0471 - val_mean_absolute_percentage_error: 1075393.0000 - val_cosine_proximity: -0.9862
#
# Epoch 00022: loss improved from 0.05434 to 0.05383, saving model to bestLstmModel.hdf5
# Epoch 23/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0535 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0535 - mean_absolute_percentage_error: 859000.5500 - cosine_proximity: -0.9867 - val_loss: 0.0473 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0473 - val_mean_absolute_percentage_error: 1083092.8750 - val_cosine_proximity: -0.9861
#
# Epoch 00023: loss improved from 0.05383 to 0.05348, saving model to bestLstmModel.hdf5
# Epoch 24/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0530 - mean_squared_error: 0.0059 - mean_absolute_error: 0.0530 - mean_absolute_percentage_error: 856955.1875 - cosine_proximity: -0.9868 - val_loss: 0.0478 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0478 - val_mean_absolute_percentage_error: 1099142.0000 - val_cosine_proximity: -0.9864
#
# Epoch 00024: loss improved from 0.05348 to 0.05303, saving model to bestLstmModel.hdf5
# Epoch 25/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0532 - mean_squared_error: 0.0058 - mean_absolute_error: 0.0532 - mean_absolute_percentage_error: 856040.9438 - cosine_proximity: -0.9870 - val_loss: 0.0465 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0465 - val_mean_absolute_percentage_error: 1053845.8750 - val_cosine_proximity: -0.9867
#
# Epoch 00025: loss did not improve from 0.05303
# Epoch 26/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0525 - mean_squared_error: 0.0057 - mean_absolute_error: 0.0525 - mean_absolute_percentage_error: 851439.8375 - cosine_proximity: -0.9871 - val_loss: 0.0466 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0466 - val_mean_absolute_percentage_error: 1089201.0000 - val_cosine_proximity: -0.9866
#
# Epoch 00026: loss improved from 0.05303 to 0.05253, saving model to bestLstmModel.hdf5
# Epoch 27/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0517 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0517 - mean_absolute_percentage_error: 850827.2906 - cosine_proximity: -0.9872 - val_loss: 0.0468 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0468 - val_mean_absolute_percentage_error: 1098816.0000 - val_cosine_proximity: -0.9866
#
# Epoch 00027: loss improved from 0.05253 to 0.05171, saving model to bestLstmModel.hdf5
# Epoch 28/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0514 - mean_squared_error: 0.0056 - mean_absolute_error: 0.0514 - mean_absolute_percentage_error: 850822.7781 - cosine_proximity: -0.9871 - val_loss: 0.0468 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0468 - val_mean_absolute_percentage_error: 1105825.2500 - val_cosine_proximity: -0.9868
#
# Epoch 00028: loss improved from 0.05171 to 0.05141, saving model to bestLstmModel.hdf5
# Epoch 29/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0511 - mean_squared_error: 0.0055 - mean_absolute_error: 0.0511 - mean_absolute_percentage_error: 848104.9906 - cosine_proximity: -0.9872 - val_loss: 0.0462 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0462 - val_mean_absolute_percentage_error: 1068521.5000 - val_cosine_proximity: -0.9869
#
# Epoch 00029: loss improved from 0.05141 to 0.05107, saving model to bestLstmModel.hdf5
# Epoch 30/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0508 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0508 - mean_absolute_percentage_error: 844951.5219 - cosine_proximity: -0.9873 - val_loss: 0.0486 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0486 - val_mean_absolute_percentage_error: 1143435.7500 - val_cosine_proximity: -0.9868
#
# Epoch 00030: loss improved from 0.05107 to 0.05082, saving model to bestLstmModel.hdf5
# Epoch 31/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0506 - mean_squared_error: 0.0054 - mean_absolute_error: 0.0506 - mean_absolute_percentage_error: 843809.0437 - cosine_proximity: -0.9874 - val_loss: 0.0459 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0459 - val_mean_absolute_percentage_error: 1089440.3750 - val_cosine_proximity: -0.9868
#
# Epoch 00031: loss improved from 0.05082 to 0.05058, saving model to bestLstmModel.hdf5
# Epoch 32/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0502 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0502 - mean_absolute_percentage_error: 840534.6281 - cosine_proximity: -0.9875 - val_loss: 0.0481 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0481 - val_mean_absolute_percentage_error: 1136117.0000 - val_cosine_proximity: -0.9868
#
# Epoch 00032: loss improved from 0.05058 to 0.05022, saving model to bestLstmModel.hdf5
# Epoch 33/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0503 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0503 - mean_absolute_percentage_error: 837176.0219 - cosine_proximity: -0.9876 - val_loss: 0.0461 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0461 - val_mean_absolute_percentage_error: 1118880.8750 - val_cosine_proximity: -0.9867
#
# Epoch 00033: loss did not improve from 0.05022
# Epoch 34/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0495 - mean_squared_error: 0.0053 - mean_absolute_error: 0.0495 - mean_absolute_percentage_error: 835267.1125 - cosine_proximity: -0.9876 - val_loss: 0.0463 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0463 - val_mean_absolute_percentage_error: 1114935.1250 - val_cosine_proximity: -0.9867
#
# Epoch 00034: loss improved from 0.05022 to 0.04946, saving model to bestLstmModel.hdf5
# Epoch 35/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0491 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0491 - mean_absolute_percentage_error: 834534.7094 - cosine_proximity: -0.9876 - val_loss: 0.0465 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0465 - val_mean_absolute_percentage_error: 1144637.8750 - val_cosine_proximity: -0.9868
# Epoch 00035: loss improved from 0.04946 to 0.04908, saving model to bestLstmModel.hdf5
# Epoch 36/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0495 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0495 - mean_absolute_percentage_error: 828275.3719 - cosine_proximity: -0.9876 - val_loss: 0.0451 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0451 - val_mean_absolute_percentage_error: 1119884.1250 - val_cosine_proximity: -0.9867
#
# Epoch 00036: loss did not improve from 0.04908
# Epoch 37/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0491 - mean_squared_error: 0.0052 - mean_absolute_error: 0.0491 - mean_absolute_percentage_error: 822169.0906 - cosine_proximity: -0.9877 - val_loss: 0.0473 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0473 - val_mean_absolute_percentage_error: 1162227.6250 - val_cosine_proximity: -0.9867
#
# Epoch 00037: loss improved from 0.04908 to 0.04908, saving model to bestLstmModel.hdf5
# Epoch 38/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0487 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0487 - mean_absolute_percentage_error: 819384.1187 - cosine_proximity: -0.9877 - val_loss: 0.0464 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0464 - val_mean_absolute_percentage_error: 1145912.1250 - val_cosine_proximity: -0.9867
#
# Epoch 00038: loss improved from 0.04908 to 0.04865, saving model to bestLstmModel.hdf5
# Epoch 39/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0485 - mean_squared_error: 0.0051 - mean_absolute_error: 0.0485 - mean_absolute_percentage_error: 815498.7094 - cosine_proximity: -0.9877 - val_loss: 0.0449 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0449 - val_mean_absolute_percentage_error: 1113331.7500 - val_cosine_proximity: -0.9867
#
# Epoch 00039: loss improved from 0.04865 to 0.04851, saving model to bestLstmModel.hdf5
# Epoch 40/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0480 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0480 - mean_absolute_percentage_error: 815543.7594 - cosine_proximity: -0.9877 - val_loss: 0.0459 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0459 - val_mean_absolute_percentage_error: 1152973.0000 - val_cosine_proximity: -0.9867
#
# Epoch 00040: loss improved from 0.04851 to 0.04796, saving model to bestLstmModel.hdf5
# Epoch 41/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0479 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0479 - mean_absolute_percentage_error: 813342.5938 - cosine_proximity: -0.9877 - val_loss: 0.0448 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0448 - val_mean_absolute_percentage_error: 1136689.7500 - val_cosine_proximity: -0.9866
#
# Epoch 00041: loss improved from 0.04796 to 0.04790, saving model to bestLstmModel.hdf5
# Epoch 42/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0481 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0481 - mean_absolute_percentage_error: 808889.7000 - cosine_proximity: -0.9877 - val_loss: 0.0444 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0444 - val_mean_absolute_percentage_error: 1105286.7500 - val_cosine_proximity: -0.9866
#
# Epoch 00042: loss did not improve from 0.04790
# Epoch 43/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0476 - mean_squared_error: 0.0050 - mean_absolute_error: 0.0476 - mean_absolute_percentage_error: 804729.3844 - cosine_proximity: -0.9877 - val_loss: 0.0441 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0441 - val_mean_absolute_percentage_error: 1118542.2500 - val_cosine_proximity: -0.9867
#
# Epoch 00043: loss improved from 0.04790 to 0.04756, saving model to bestLstmModel.hdf5
# Epoch 44/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0475 - mean_squared_error: 0.0049 - mean_absolute_error: 0.0475 - mean_absolute_percentage_error: 801903.6969 - cosine_proximity: -0.9877 - val_loss: 0.0442 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 1100824.3750 - val_cosine_proximity: -0.9866
#
# Epoch 00044: loss improved from 0.04756 to 0.04746, saving model to bestLstmModel.hdf5
# Epoch 45/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0476 - mean_squared_error: 0.0049 - mean_absolute_error: 0.0476 - mean_absolute_percentage_error: 797880.7156 - cosine_proximity: -0.9877 - val_loss: 0.0444 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0444 - val_mean_absolute_percentage_error: 1130005.0000 - val_cosine_proximity: -0.9866
#
# Epoch 00045: loss did not improve from 0.04746
# Epoch 46/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0473 - mean_squared_error: 0.0049 - mean_absolute_error: 0.0473 - mean_absolute_percentage_error: 796193.8969 - cosine_proximity: -0.9877 - val_loss: 0.0441 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0441 - val_mean_absolute_percentage_error: 1111076.0000 - val_cosine_proximity: -0.9867
#
# Epoch 00046: loss improved from 0.04746 to 0.04730, saving model to bestLstmModel.hdf5
# Epoch 47/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0474 - mean_squared_error: 0.0049 - mean_absolute_error: 0.0474 - mean_absolute_percentage_error: 793687.4719 - cosine_proximity: -0.9877 - val_loss: 0.0438 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0438 - val_mean_absolute_percentage_error: 1111862.7500 - val_cosine_proximity: -0.9867
#
# Epoch 00047: loss did not improve from 0.04730
# Epoch 48/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0469 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0469 - mean_absolute_percentage_error: 789560.1250 - cosine_proximity: -0.9877 - val_loss: 0.0445 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0445 - val_mean_absolute_percentage_error: 1112015.0000 - val_cosine_proximity: -0.9866
#
# Epoch 00048: loss improved from 0.04730 to 0.04690, saving model to bestLstmModel.hdf5
# Epoch 49/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0467 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0467 - mean_absolute_percentage_error: 788515.3688 - cosine_proximity: -0.9877 - val_loss: 0.0453 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0453 - val_mean_absolute_percentage_error: 1143898.2500 - val_cosine_proximity: -0.9865
#
# Epoch 00049: loss improved from 0.04690 to 0.04671, saving model to bestLstmModel.hdf5
# Epoch 50/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0469 - mean_squared_error: 0.0048 - mean_absolute_error: 0.0469 - mean_absolute_percentage_error: 787972.9094 - cosine_proximity: -0.9877 - val_loss: 0.0438 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0438 - val_mean_absolute_percentage_error: 1114087.1250 - val_cosine_proximity: -0.9866
#
# Epoch 00050: loss did not improve from 0.04671
# Epoch 51/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0464 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0464 - mean_absolute_percentage_error: 782058.7688 - cosine_proximity: -0.9878 - val_loss: 0.0451 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0451 - val_mean_absolute_percentage_error: 1143259.1250 - val_cosine_proximity: -0.9866
#
# Epoch 00051: loss improved from 0.04671 to 0.04643, saving model to bestLstmModel.hdf5
# Epoch 52/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0464 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0464 - mean_absolute_percentage_error: 781698.0687 - cosine_proximity: -0.9877 - val_loss: 0.0472 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0472 - val_mean_absolute_percentage_error: 1169782.5000 - val_cosine_proximity: -0.9865
#
# Epoch 00052: loss improved from 0.04643 to 0.04638, saving model to bestLstmModel.hdf5
# Epoch 53/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0463 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0463 - mean_absolute_percentage_error: 782970.8656 - cosine_proximity: -0.9878 - val_loss: 0.0442 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 1104496.6250 - val_cosine_proximity: -0.9865
# Epoch 00053: loss improved from 0.04638 to 0.04630, saving model to bestLstmModel.hdf5
# Epoch 54/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0464 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0464 - mean_absolute_percentage_error: 780881.7063 - cosine_proximity: -0.9878 - val_loss: 0.0442 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 1124131.6250 - val_cosine_proximity: -0.9867
#
# Epoch 00054: loss did not improve from 0.04630
# Epoch 55/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0465 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0465 - mean_absolute_percentage_error: 781198.3438 - cosine_proximity: -0.9878 - val_loss: 0.0460 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0460 - val_mean_absolute_percentage_error: 1159887.8750 - val_cosine_proximity: -0.9867
#
# Epoch 00055: loss did not improve from 0.04630
# Epoch 56/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0463 - mean_squared_error: 0.0047 - mean_absolute_error: 0.0463 - mean_absolute_percentage_error: 781080.1094 - cosine_proximity: -0.9878 - val_loss: 0.0443 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0443 - val_mean_absolute_percentage_error: 1110924.5000 - val_cosine_proximity: -0.9866
#
# Epoch 00056: loss did not improve from 0.04630
# Epoch 57/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0460 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0460 - mean_absolute_percentage_error: 781012.4719 - cosine_proximity: -0.9878 - val_loss: 0.0445 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0445 - val_mean_absolute_percentage_error: 1120881.6250 - val_cosine_proximity: -0.9867
#
# Epoch 00057: loss improved from 0.04630 to 0.04602, saving model to bestLstmModel.hdf5
# Epoch 58/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0458 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0458 - mean_absolute_percentage_error: 777593.7375 - cosine_proximity: -0.9878 - val_loss: 0.0451 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0451 - val_mean_absolute_percentage_error: 1142791.3750 - val_cosine_proximity: -0.9864
#
# Epoch 00058: loss improved from 0.04602 to 0.04576, saving model to bestLstmModel.hdf5
# Epoch 59/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0460 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0460 - mean_absolute_percentage_error: 777593.1906 - cosine_proximity: -0.9878 - val_loss: 0.0442 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0442 - val_mean_absolute_percentage_error: 1119633.2500 - val_cosine_proximity: -0.9867
#
# Epoch 00059: loss did not improve from 0.04576
# Epoch 60/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0460 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0460 - mean_absolute_percentage_error: 778467.3812 - cosine_proximity: -0.9878 - val_loss: 0.0462 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0462 - val_mean_absolute_percentage_error: 1139575.0000 - val_cosine_proximity: -0.9867
#
# Epoch 00060: loss did not improve from 0.04576
# Epoch 61/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0457 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0457 - mean_absolute_percentage_error: 776280.9844 - cosine_proximity: -0.9878 - val_loss: 0.0458 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 1172167.6250 - val_cosine_proximity: -0.9867
#
# Epoch 00061: loss improved from 0.04576 to 0.04571, saving model to bestLstmModel.hdf5
# Epoch 62/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0457 - mean_squared_error: 0.0046 - mean_absolute_error: 0.0457 - mean_absolute_percentage_error: 776883.9875 - cosine_proximity: -0.9878 - val_loss: 0.0457 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0457 - val_mean_absolute_percentage_error: 1149323.3750 - val_cosine_proximity: -0.9868
#
# Epoch 00062: loss improved from 0.04571 to 0.04569, saving model to bestLstmModel.hdf5
# Epoch 63/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0456 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0456 - mean_absolute_percentage_error: 776653.3688 - cosine_proximity: -0.9878 - val_loss: 0.0448 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0448 - val_mean_absolute_percentage_error: 1117138.6250 - val_cosine_proximity: -0.9867
#
# Epoch 00063: loss improved from 0.04569 to 0.04562, saving model to bestLstmModel.hdf5
# Epoch 64/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0457 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0457 - mean_absolute_percentage_error: 774032.0031 - cosine_proximity: -0.9878 - val_loss: 0.0445 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0445 - val_mean_absolute_percentage_error: 1122967.0000 - val_cosine_proximity: -0.9867
#
# Epoch 00064: loss did not improve from 0.04562
# Epoch 65/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0454 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0454 - mean_absolute_percentage_error: 772919.9250 - cosine_proximity: -0.9879 - val_loss: 0.0466 - val_mean_squared_error: 0.0047 - val_mean_absolute_error: 0.0466 - val_mean_absolute_percentage_error: 1160316.6250 - val_cosine_proximity: -0.9868
#
# Epoch 00065: loss improved from 0.04562 to 0.04539, saving model to bestLstmModel.hdf5
# Epoch 66/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0457 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0457 - mean_absolute_percentage_error: 776957.8125 - cosine_proximity: -0.9879 - val_loss: 0.0448 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0448 - val_mean_absolute_percentage_error: 1106979.3750 - val_cosine_proximity: -0.9868
#
# Epoch 00066: loss did not improve from 0.04539
# Epoch 67/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0457 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0457 - mean_absolute_percentage_error: 776283.8812 - cosine_proximity: -0.9879 - val_loss: 0.0454 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0454 - val_mean_absolute_percentage_error: 1140550.7500 - val_cosine_proximity: -0.9868
#
# Epoch 00067: loss did not improve from 0.04539
# Epoch 68/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0457 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0457 - mean_absolute_percentage_error: 776122.7000 - cosine_proximity: -0.9878 - val_loss: 0.0452 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0452 - val_mean_absolute_percentage_error: 1106872.6250 - val_cosine_proximity: -0.9866
#
# Epoch 00068: loss did not improve from 0.04539
# Epoch 69/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0453 - mean_squared_error: 0.0045 - mean_absolute_error: 0.0453 - mean_absolute_percentage_error: 774587.0563 - cosine_proximity: -0.9879 - val_loss: 0.0449 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0449 - val_mean_absolute_percentage_error: 1114039.3750 - val_cosine_proximity: -0.9867
#
# Epoch 00069: loss improved from 0.04539 to 0.04533, saving model to bestLstmModel.hdf5
# Epoch 70/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0452 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0452 - mean_absolute_percentage_error: 773204.7750 - cosine_proximity: -0.9879 - val_loss: 0.0458 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 1154683.1250 - val_cosine_proximity: -0.9867
#
# Epoch 00070: loss improved from 0.04533 to 0.04517, saving model to bestLstmModel.hdf5
# Epoch 71/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0452 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0452 - mean_absolute_percentage_error: 775454.4656 - cosine_proximity: -0.9879 - val_loss: 0.0450 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0450 - val_mean_absolute_percentage_error: 1138563.6250 - val_cosine_proximity: -0.9868
#
# Epoch 00071: loss did not improve from 0.04517
# Epoch 72/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0452 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0452 - mean_absolute_percentage_error: 773378.0781 - cosine_proximity: -0.9879 - val_loss: 0.0477 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0477 - val_mean_absolute_percentage_error: 1171922.5000 - val_cosine_proximity: -0.9868
#
# Epoch 00072: loss did not improve from 0.04517
# Epoch 73/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0451 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0451 - mean_absolute_percentage_error: 776558.9437 - cosine_proximity: -0.9879 - val_loss: 0.0457 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0457 - val_mean_absolute_percentage_error: 1141998.8750 - val_cosine_proximity: -0.9868
#
# Epoch 00073: loss improved from 0.04517 to 0.04509, saving model to bestLstmModel.hdf5
# Epoch 74/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0451 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0451 - mean_absolute_percentage_error: 774598.9688 - cosine_proximity: -0.9879 - val_loss: 0.0468 - val_mean_squared_error: 0.0047 - val_mean_absolute_error: 0.0468 - val_mean_absolute_percentage_error: 1164485.2500 - val_cosine_proximity: -0.9869
#
# Epoch 00074: loss did not improve from 0.04509
# Epoch 75/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0450 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0450 - mean_absolute_percentage_error: 775270.1062 - cosine_proximity: -0.9879 - val_loss: 0.0458 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 1156268.3750 - val_cosine_proximity: -0.9868
#
# Epoch 00075: loss improved from 0.04509 to 0.04502, saving model to bestLstmModel.hdf5
# Epoch 76/100
# 20/20 [==============================] - 0s 22ms/step - loss: 0.0455 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0455 - mean_absolute_percentage_error: 775724.0406 - cosine_proximity: -0.9879 - val_loss: 0.0454 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0454 - val_mean_absolute_percentage_error: 1112761.0000 - val_cosine_proximity: -0.9868
#
# Epoch 00076: loss did not improve from 0.04502
# Epoch 77/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0449 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0449 - mean_absolute_percentage_error: 773056.3688 - cosine_proximity: -0.9879 - val_loss: 0.0456 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0456 - val_mean_absolute_percentage_error: 1118971.6250 - val_cosine_proximity: -0.9868
#
# Epoch 00077: loss improved from 0.04502 to 0.04495, saving model to bestLstmModel.hdf5
# Epoch 78/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0450 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0450 - mean_absolute_percentage_error: 774785.5062 - cosine_proximity: -0.9879 - val_loss: 0.0468 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0468 - val_mean_absolute_percentage_error: 1144486.7500 - val_cosine_proximity: -0.9868
#
# Epoch 00078: loss did not improve from 0.04495
# Epoch 79/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0449 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0449 - mean_absolute_percentage_error: 775713.8250 - cosine_proximity: -0.9879 - val_loss: 0.0462 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0462 - val_mean_absolute_percentage_error: 1155595.1250 - val_cosine_proximity: -0.9868
#
# Epoch 00079: loss improved from 0.04495 to 0.04491, saving model to bestLstmModel.hdf5
# Epoch 80/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0449 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0449 - mean_absolute_percentage_error: 773863.4500 - cosine_proximity: -0.9879 - val_loss: 0.0464 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0464 - val_mean_absolute_percentage_error: 1161095.1250 - val_cosine_proximity: -0.9868
#
# Epoch 00080: loss improved from 0.04491 to 0.04486, saving model to bestLstmModel.hdf5
# Epoch 81/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0448 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0448 - mean_absolute_percentage_error: 774946.0594 - cosine_proximity: -0.9879 - val_loss: 0.0453 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0453 - val_mean_absolute_percentage_error: 1134119.6250 - val_cosine_proximity: -0.9868
#
# Epoch 00081: loss improved from 0.04486 to 0.04477, saving model to bestLstmModel.hdf5
# Epoch 82/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0451 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0451 - mean_absolute_percentage_error: 774976.7438 - cosine_proximity: -0.9880 - val_loss: 0.0458 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 1141373.7500 - val_cosine_proximity: -0.9867
#
# Epoch 00082: loss did not improve from 0.04477
# Epoch 83/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0447 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0447 - mean_absolute_percentage_error: 775431.7656 - cosine_proximity: -0.9879 - val_loss: 0.0470 - val_mean_squared_error: 0.0047 - val_mean_absolute_error: 0.0470 - val_mean_absolute_percentage_error: 1165902.0000 - val_cosine_proximity: -0.9868
#
# Epoch 00083: loss improved from 0.04477 to 0.04473, saving model to bestLstmModel.hdf5
# Epoch 84/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0448 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0448 - mean_absolute_percentage_error: 775200.4437 - cosine_proximity: -0.9880 - val_loss: 0.0461 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0461 - val_mean_absolute_percentage_error: 1161561.1250 - val_cosine_proximity: -0.9868
#
# Epoch 00084: loss did not improve from 0.04473
# Epoch 85/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0446 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0446 - mean_absolute_percentage_error: 774838.0875 - cosine_proximity: -0.9879 - val_loss: 0.0462 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0462 - val_mean_absolute_percentage_error: 1172306.0000 - val_cosine_proximity: -0.9867
#
# Epoch 00085: loss improved from 0.04473 to 0.04463, saving model to bestLstmModel.hdf5
# Epoch 86/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0449 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0449 - mean_absolute_percentage_error: 774809.4969 - cosine_proximity: -0.9880 - val_loss: 0.0472 - val_mean_squared_error: 0.0047 - val_mean_absolute_error: 0.0472 - val_mean_absolute_percentage_error: 1173231.1250 - val_cosine_proximity: -0.9868
#
# Epoch 00086: loss did not improve from 0.04463
# Epoch 87/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0448 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0448 - mean_absolute_percentage_error: 776271.8969 - cosine_proximity: -0.9880 - val_loss: 0.0460 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0460 - val_mean_absolute_percentage_error: 1157120.8750 - val_cosine_proximity: -0.9868
#
# Epoch 00087: loss did not improve from 0.04463
# Epoch 88/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0445 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0445 - mean_absolute_percentage_error: 774207.2438 - cosine_proximity: -0.9880 - val_loss: 0.0461 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0461 - val_mean_absolute_percentage_error: 1140090.6250 - val_cosine_proximity: -0.9868
#
# Epoch 00088: loss improved from 0.04463 to 0.04454, saving model to bestLstmModel.hdf5
# Epoch 89/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0447 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0447 - mean_absolute_percentage_error: 775536.6625 - cosine_proximity: -0.9880 - val_loss: 0.0478 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0478 - val_mean_absolute_percentage_error: 1170140.3750 - val_cosine_proximity: -0.9868
#
# Epoch 00089: loss did not improve from 0.04454
# Epoch 90/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0445 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0445 - mean_absolute_percentage_error: 775897.6906 - cosine_proximity: -0.9880 - val_loss: 0.0459 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0459 - val_mean_absolute_percentage_error: 1162391.3750 - val_cosine_proximity: -0.9868
#
# Epoch 00090: loss improved from 0.04454 to 0.04450, saving model to bestLstmModel.hdf5
# Epoch 91/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0447 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0447 - mean_absolute_percentage_error: 775715.7937 - cosine_proximity: -0.9880 - val_loss: 0.0456 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0456 - val_mean_absolute_percentage_error: 1144801.1250 - val_cosine_proximity: -0.9868
#
# Epoch 00091: loss did not improve from 0.04450
# Epoch 92/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0448 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0448 - mean_absolute_percentage_error: 775892.7094 - cosine_proximity: -0.9880 - val_loss: 0.0458 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 1145179.7500 - val_cosine_proximity: -0.9868
#
# Epoch 00092: loss did not improve from 0.04450
# Epoch 93/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0445 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0445 - mean_absolute_percentage_error: 777010.3219 - cosine_proximity: -0.9880 - val_loss: 0.0460 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0460 - val_mean_absolute_percentage_error: 1169571.5000 - val_cosine_proximity: -0.9867
#
# Epoch 00093: loss improved from 0.04450 to 0.04449, saving model to bestLstmModel.hdf5
# Epoch 94/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0443 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0443 - mean_absolute_percentage_error: 776373.7188 - cosine_proximity: -0.9880 - val_loss: 0.0463 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0463 - val_mean_absolute_percentage_error: 1163734.3750 - val_cosine_proximity: -0.9867
#
# Epoch 00094: loss improved from 0.04449 to 0.04431, saving model to bestLstmModel.hdf5
# Epoch 95/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0444 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0444 - mean_absolute_percentage_error: 776667.3000 - cosine_proximity: -0.9881 - val_loss: 0.0459 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0459 - val_mean_absolute_percentage_error: 1144878.8750 - val_cosine_proximity: -0.9868
#
# Epoch 00095: loss did not improve from 0.04431
# Epoch 96/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0446 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0446 - mean_absolute_percentage_error: 777676.3688 - cosine_proximity: -0.9880 - val_loss: 0.0458 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 1137913.7500 - val_cosine_proximity: -0.9868
#
# Epoch 00096: loss did not improve from 0.04431
# Epoch 97/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0445 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0445 - mean_absolute_percentage_error: 776350.9875 - cosine_proximity: -0.9881 - val_loss: 0.0475 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0475 - val_mean_absolute_percentage_error: 1173798.0000 - val_cosine_proximity: -0.9868
#
# Epoch 00097: loss did not improve from 0.04431
# Epoch 98/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0446 - mean_squared_error: 0.0043 - mean_absolute_error: 0.0446 - mean_absolute_percentage_error: 777236.6281 - cosine_proximity: -0.9881 - val_loss: 0.0460 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0460 - val_mean_absolute_percentage_error: 1137542.0000 - val_cosine_proximity: -0.9866
#
# Epoch 00098: loss did not improve from 0.04431
# Epoch 99/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0445 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0445 - mean_absolute_percentage_error: 777543.3562 - cosine_proximity: -0.9881 - val_loss: 0.0477 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0477 - val_mean_absolute_percentage_error: 1187177.0000 - val_cosine_proximity: -0.9867
#
# Epoch 00099: loss did not improve from 0.04431
# Epoch 100/100
# 20/20 [==============================] - 0s 21ms/step - loss: 0.0444 - mean_squared_error: 0.0042 - mean_absolute_error: 0.0444 - mean_absolute_percentage_error: 778577.4906 - cosine_proximity: -0.9881 - val_loss: 0.0458 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0458 - val_mean_absolute_percentage_error: 1148265.5000 - val_cosine_proximity: -0.9867
#
# Epoch 00100: loss did not improve from 0.04431

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('mean_squared_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('mean_absolute_percentage_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['cosine_proximity'])
plt.plot(history.history['val_cosine_proximity'])
plt.title('cosine_proximity')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
Xt = model.predict(X_test)
plt.figure(figsize = (15,10))

for i in range(0,len(Xt)):
    plt.plot([x + i*forward_days for x in range(len(Xt[i]))], scl.inverse_transform(Xt[i].reshape(-1,1)), color='r')
    
plt.plot(0, scl.inverse_transform(Xt[i].reshape(-1,1))[0], color='r', label='Prediction') 
    
plt.plot(scl.inverse_transform(y_test.reshape(-1,1)), label='Target')
plt.legend(loc='best')
plt.show()

# %%
_data,y_data = processData(array,look_back,forward_days,forward_days)
Xt = model.predict(_data)
plt.figure(figsize = (15,10))
for i in range(0,len(Xt)):
    plt.plot([x + i*forward_days for x in range(len(Xt[i]))], scl.inverse_transform(Xt[i].reshape(-1,1)), color='r')
    
plt.plot(0, scl.inverse_transform(Xt[i].reshape(-1,1))[0], color='r', label='Prediction') #only to place the label
    
plt.plot(scl.inverse_transform(y_data.reshape(-1,1)), label='Target')
plt.legend(loc='best')
plt.show()

# %%
division = len(array) - num_periods*forward_days

leftover = division%forward_days+1

array_test = array[division-look_back:]
array_train = array[leftover:division]
Xtrain,ytrain = processData(array_train,look_back,forward_days,forward_days)
Xtest,ytest = processData(array_test,look_back,forward_days,forward_days)
Xtrain = model.predict(Xtrain)
Xtrain = Xtrain.ravel()

Xtest = model.predict(Xtest)
Xtest = Xtest.ravel()

y = np.concatenate((ytrain, ytest), axis=0)
plt.figure(figsize = (15,10))

# Data in Train/Validation
plt.plot([x for x in range(look_back+leftover, len(Xtrain)+look_back+leftover)], scl.inverse_transform(Xtrain.reshape(-1,1)), color='r', label='Train')
# Data in Test
plt.plot([x for x in range(look_back +leftover+ len(Xtrain), len(Xtrain)+len(Xtest)+look_back+leftover)], scl.inverse_transform(Xtest.reshape(-1,1)), color='y', label='Test')

#Data used
plt.plot([x for x in range(look_back+leftover, look_back+leftover+len(Xtrain)+len(Xtest))], scl.inverse_transform(y.reshape(-1,1)), color='b', label='Target')

#Initial data. It should overlap the data used
#plt.plot(scl.inverse_transform(array), color='b', label='Esperado')

plt.legend(loc='best')
plt.show()
