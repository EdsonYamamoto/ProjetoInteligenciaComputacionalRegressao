# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import math
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend as K

from sklearn.preprocessing import MinMaxScaler
import requests
# Out:
# Using TensorFlow backend.

# %%
urlPost = "https://marketdata.websol.barchart.com/getHistory.csv?apikey=958bd129b997922724b5242bdcc8cf9d&symbol=IBM&type=minutes&startDate=20200101&endDate=20200201&interval=60&order=asc&sessionFilter=EFK&splits=true÷nds=true&volume=sum&nearby=1&jerq=true"

myobj = {
    'apikey':'958bd129b997922724b5242bdcc8cf9d',
}

x = requests.post(urlPost, data = myobj)

f = open("dataset2.csv", "w")
f.write(x.text)
f.close()

# %%
urlPost = "https://marketdata.websol.barchart.com/getHistory.csv"

# %%
dataframe = pd.read_csv("dataset.csv")

# %%
dataframe[0:5]
# Out:
#   symbol         timestamp  tradingDay    open    high      low    close  \
# 0   GOOG  11/05/2020 11:45  11/05/2020   13996   13996   139829  1399037
# 1   GOOG  11/05/2020 11:50  11/05/2020  139892  139939  1398323   139879
# 2   GOOG  11/05/2020 11:55  11/05/2020  139891  139952   139846   139952
# 3   GOOG  11/05/2020 12:00  11/05/2020  139906  139967     1399   139909
# 4   GOOG  11/05/2020 12:05  11/05/2020  139943  139977    13981    13981
#
#    volume
# 0    7567
# 1    3968
# 2    4819
# 3    5142
# 4   11500

# %%
dataframe.describe()
# Out:
#                open          high           low         close         volume
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000
# mean   4.396000e+05  3.608101e+05  3.566961e+05  5.028537e+05   11668.873000
# std    5.532629e+05  5.040311e+05  5.006725e+05  5.851585e+05   16413.958367
# min    1.335000e+03  1.336000e+03  1.339000e+03  1.330000e+03    1885.000000
# 25%    1.371145e+05  1.358150e+05  1.349555e+05  1.375618e+05    5846.000000
# 50%    1.403570e+05  1.403150e+05  1.399490e+05  1.405410e+05    8026.000000
# 75%    4.398490e+05  1.429055e+05  1.426028e+05  1.357773e+06   11364.000000
# max    1.440096e+06  1.440005e+06  1.438216e+06  1.439565e+06  251891.000000

# %%
plt.figure(figsize = (15,10))
plt.plot(dataframe['close'], label='GOOG')
plt.legend(loc='best')
plt.show()

# %%
dataframe["timestamp"] = pd.to_datetime(dataframe["timestamp"]).values.astype(np.int64) 
dataframe = dataframe.drop(["tradingDay"], axis=1)

dataframe['symbol'] = pd.factorize(dataframe['symbol'])[0] + 1

# %%
dataframe[0:5]
# Out:
#    symbol            timestamp    open    high      low    close  volume
# 0       1  1604576700000000000   13996   13996   139829  1399037    7567
# 1       1  1604577000000000000  139892  139939  1398323   139879    3968
# 2       1  1604577300000000000  139891  139952   139846   139952    4819
# 3       1  1604577600000000000  139906  139967     1399   139909    5142
# 4       1  1604577900000000000  139943  139977    13981    13981   11500

# %%
dataframe.describe()
# Out:
#        symbol     timestamp          open          high           low  \
# count  1000.0  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean      1.0  1.592117e+18  4.396000e+05  3.608101e+05  3.566961e+05
# std       0.0  5.483014e+15  5.532629e+05  5.040311e+05  5.006725e+05
# min       1.0  1.589362e+18  1.335000e+03  1.336000e+03  1.339000e+03
# 25%       1.0  1.589798e+18  1.371145e+05  1.358150e+05  1.349555e+05
# 50%       1.0  1.590061e+18  1.403570e+05  1.403150e+05  1.399490e+05
# 75%       1.0  1.590583e+18  4.398490e+05  1.429055e+05  1.426028e+05
# max       1.0  1.607184e+18  1.440096e+06  1.440005e+06  1.438216e+06
#
#               close         volume
# count  1.000000e+03    1000.000000
# mean   5.028537e+05   11668.873000
# std    5.851585e+05   16413.958367
# min    1.330000e+03    1885.000000
# 25%    1.375618e+05    5846.000000
# 50%    1.405410e+05    8026.000000
# 75%    1.357773e+06   11364.000000
# max    1.439565e+06  251891.000000

# %%
plt.figure(figsize = (15,10))
plt.plot(dataframe[:200]['close'], label='GOOG')
#plt.plot(dataframe['timestamp'], label='GOOG')
plt.legend(loc='best')
plt.show()

# %%
dataframe['close'].plot(kind="hist")

# %%
dataframe = dataframe[dataframe['close'] > 150000]

# %%
plt.figure(figsize = (15,10))
plt.plot(dataframe['close'], label='GOOG')
#plt.plot(dataframe['timestamp'], label='GOOG')
plt.legend(loc='best')
plt.show()

# %%
X = dataframe.drop(["close"], axis=1)
y = dataframe["close"]

look_back = 10
forward_days = 10
num_periods = 20
lstmPrimeiraLayer = 50
lstmSegundaLayer = 30

array = dataframe["close"].values.reshape(dataframe["close"].shape[0],1)

scl = MinMaxScaler()
array = scl.fit_transform(array)

division = len(array) - num_periods*forward_days

array_test = array[division-look_back:]
array_train = array[:division]

def processData(data, look_back, forward_days,jump=1):
    X,Y = [],[]
    for i in range(0,len(data) -look_back -forward_days +1, jump):
        X.append(data[i:(i+look_back)])
        Y.append(data[(i+look_back):(i+look_back+forward_days)])
    return np.array(X),np.array(Y)


_test,y_test = processData(array_test,look_back,forward_days,forward_days)
y_test = np.array([list(a.ravel()) for a in y_test])

X,y = processData(array_train,look_back,forward_days)
y = np.array([list(a.ravel()) for a in y])


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
nEpocas = 10
steps_per_epoch = 10
VALIDATION_SIZE = 1
BATCH_SIZE = 16
checkpoint = "bestModel.hdf5"

# %%
model = Sequential()

model.add(LSTM(units=lstmPrimeiraLayer, input_shape=(look_back,1), return_sequences=True))

model.add(LSTM(units=lstmSegundaLayer,input_shape=(lstmPrimeiraLayer,1)))

model.add(Dense(units=forward_days, activation='linear'))

model.compile(loss='mean_absolute_error', optimizer='adam', metrics = ['mse', 'mae', 'mape', 'cosine'])

mc = ModelCheckpoint(checkpoint, monitor='loss', verbose=1, save_best_only=True, mode='min')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100, min_delta=0.000001)

# fit the model
compute_steps_per_epoch = lambda x: int(math.ceil(1. * x / BATCH_SIZE))
val_steps = compute_steps_per_epoch(VALIDATION_SIZE)

#batch_size = numero de execuções antes de atualizar os erros.
history = model.fit( X_train, y_train, epochs=nEpocas, steps_per_epoch=steps_per_epoch, callbacks=[es, mc], validation_steps = val_steps, validation_data=(X_test, y_test))
# Out:
# Train on 54 samples, validate on 28 samples
# Epoch 1/10
# 10/10 [==============================] - 4s 360ms/step - loss: 0.3346 - mean_squared_error: 0.1799 - mean_absolute_error: 0.3346 - mean_absolute_percentage_error: 355600.0719 - cosine_proximity: -0.5090 - val_loss: 0.2953 - val_mean_squared_error: 0.1454 - val_mean_absolute_error: 0.2953 - val_mean_absolute_percentage_error: 259730.2500 - val_cosine_proximity: -0.8224
#
# Epoch 00001: loss improved from inf to 0.33465, saving model to bestModelTextGen2.hdf5
# Epoch 2/10
# 10/10 [==============================] - 0s 29ms/step - loss: 0.2308 - mean_squared_error: 0.0989 - mean_absolute_error: 0.2308 - mean_absolute_percentage_error: 1607586.7250 - cosine_proximity: -0.8445 - val_loss: 0.1834 - val_mean_squared_error: 0.0572 - val_mean_absolute_error: 0.1834 - val_mean_absolute_percentage_error: 1050530.2500 - val_cosine_proximity: -0.9015
#
# Epoch 00002: loss improved from 0.33465 to 0.23083, saving model to bestModelTextGen2.hdf5
# Epoch 3/10
# 10/10 [==============================] - 0s 29ms/step - loss: 0.1482 - mean_squared_error: 0.0371 - mean_absolute_error: 0.1482 - mean_absolute_percentage_error: 2862827.1000 - cosine_proximity: -0.9342 - val_loss: 0.1221 - val_mean_squared_error: 0.0236 - val_mean_absolute_error: 0.1221 - val_mean_absolute_percentage_error: 2062372.0000 - val_cosine_proximity: -0.9659
#
# Epoch 00003: loss improved from 0.23083 to 0.14816, saving model to bestModelTextGen2.hdf5
# Epoch 4/10
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0992 - mean_squared_error: 0.0186 - mean_absolute_error: 0.0992 - mean_absolute_percentage_error: 1945779.0000 - cosine_proximity: -0.9641 - val_loss: 0.0968 - val_mean_squared_error: 0.0178 - val_mean_absolute_error: 0.0968 - val_mean_absolute_percentage_error: 1740961.6250 - val_cosine_proximity: -0.9565
#
# Epoch 00004: loss improved from 0.14816 to 0.09923, saving model to bestModelTextGen2.hdf5
# Epoch 5/10
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0813 - mean_squared_error: 0.0144 - mean_absolute_error: 0.0813 - mean_absolute_percentage_error: 1122515.1687 - cosine_proximity: -0.9589 - val_loss: 0.0905 - val_mean_squared_error: 0.0154 - val_mean_absolute_error: 0.0905 - val_mean_absolute_percentage_error: 1267936.7500 - val_cosine_proximity: -0.9604
#
# Epoch 00005: loss improved from 0.09923 to 0.08128, saving model to bestModelTextGen2.hdf5
# Epoch 6/10
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0765 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0765 - mean_absolute_percentage_error: 1068909.1188 - cosine_proximity: -0.9684 - val_loss: 0.0844 - val_mean_squared_error: 0.0146 - val_mean_absolute_error: 0.0844 - val_mean_absolute_percentage_error: 1374966.1250 - val_cosine_proximity: -0.9702
#
# Epoch 00006: loss improved from 0.08128 to 0.07648, saving model to bestModelTextGen2.hdf5
# Epoch 7/10
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0719 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0719 - mean_absolute_percentage_error: 1384046.8375 - cosine_proximity: -0.9725 - val_loss: 0.0812 - val_mean_squared_error: 0.0141 - val_mean_absolute_error: 0.0812 - val_mean_absolute_percentage_error: 1469298.7500 - val_cosine_proximity: -0.9754
#
# Epoch 00007: loss improved from 0.07648 to 0.07194, saving model to bestModelTextGen2.hdf5
# Epoch 8/10
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0694 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0694 - mean_absolute_percentage_error: 1540691.1125 - cosine_proximity: -0.9742 - val_loss: 0.0788 - val_mean_squared_error: 0.0130 - val_mean_absolute_error: 0.0788 - val_mean_absolute_percentage_error: 1420540.6250 - val_cosine_proximity: -0.9764
#
# Epoch 00008: loss improved from 0.07194 to 0.06938, saving model to bestModelTextGen2.hdf5
# Epoch 9/10
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0672 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0672 - mean_absolute_percentage_error: 1496561.3250 - cosine_proximity: -0.9747 - val_loss: 0.0761 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0761 - val_mean_absolute_percentage_error: 1341302.1250 - val_cosine_proximity: -0.9766
#
# Epoch 00009: loss improved from 0.06938 to 0.06723, saving model to bestModelTextGen2.hdf5
# Epoch 10/10
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0655 - mean_squared_error: 0.0100 - mean_absolute_error: 0.0655 - mean_absolute_percentage_error: 1472603.3125 - cosine_proximity: -0.9748 - val_loss: 0.0738 - val_mean_squared_error: 0.0109 - val_mean_absolute_error: 0.0738 - val_mean_absolute_percentage_error: 1328712.6250 - val_cosine_proximity: -0.9771
#
# Epoch 00010: loss improved from 0.06723 to 0.06549, saving model to bestModelTextGen2.hdf5

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('mean_squared_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('mean_absolute_percentage_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['cosine_proximity'])
plt.plot(history.history['val_cosine_proximity'])
plt.title('cosine_proximity')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
Xt = model.predict(X_test)
plt.figure(figsize = (15,10))

for i in range(0,len(Xt)):
    plt.plot([x + i*forward_days for x in range(len(Xt[i]))], scl.inverse_transform(Xt[i].reshape(-1,1)), color='r')
    
plt.plot(0, scl.inverse_transform(Xt[i].reshape(-1,1))[0], color='r', label='Prediction') #only to place the label
    
plt.plot(scl.inverse_transform(y_test.reshape(-1,1)), label='Target')
plt.legend(loc='best')
plt.show()

# %%
_data,y_data = processData(array,look_back,forward_days,forward_days)
Xt = model.predict(_data)
plt.figure(figsize = (15,10))

for i in range(0,len(Xt)):
    plt.plot([x + i*forward_days for x in range(len(Xt[i]))], scl.inverse_transform(Xt[i].reshape(-1,1)), color='r')
    
plt.plot(0, scl.inverse_transform(Xt[i].reshape(-1,1))[0], color='r', label='Prediction') #only to place the label
    
plt.plot(scl.inverse_transform(y_data.reshape(-1,1)), label='Target')
plt.legend(loc='best')
plt.show()

# %%
def soft_acc(y_true, y_pred):
    return K.mean(K.equal(K.round(y_true), K.round(y_pred)))

model = Sequential()

model.add(Embedding(output_dim=64, input_dim=len (X.columns) ))

model.add(LSTM(128, return_sequences=True))

model.add(LSTM(128, return_sequences=True))

model.add(LSTM(64, return_sequences=True))

model.add(LSTM(64, return_sequences=True))

model.add(Dropout(0.5))

model.add(LSTM(32, return_sequences=False))

model.add(Dense(units=1, activation='linear'))

model.compile(loss='mean_absolute_error', optimizer='adam', metrics = ['mse', 'mae', 'mape', 'cosine'])

mc = ModelCheckpoint(checkpoint, monitor='loss', verbose=1, save_best_only=True, mode='min')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100, min_delta=0.000001)

# fit the model
compute_steps_per_epoch = lambda x: int(math.ceil(1. * x / BATCH_SIZE))
val_steps = compute_steps_per_epoch(VALIDATION_SIZE)

#batch_size = numero de execuções antes de atualizar os erros.
history = model.fit( X_train, y_train, epochs=nEpocas, steps_per_epoch=steps_per_epoch, callbacks=[es, mc], validation_steps = val_steps, validation_data=(X_test, y_test))

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('mean_squared_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('mean_absolute_percentage_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['cosine_proximity'])
plt.plot(history.history['val_cosine_proximity'])
plt.title('cosine_proximity')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('mean_squared_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('mean_absolute_percentage_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['cosine_proximity'])
plt.plot(history.history['val_cosine_proximity'])
plt.title('cosine_proximity')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
