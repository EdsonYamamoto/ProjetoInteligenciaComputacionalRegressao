# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import math
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend as K

import requests

# %%
urlPost = "https://marketdata.websol.barchart.com/getHistory.csv?apikey=958bd129b997922724b5242bdcc8cf9d&symbol=IBM&type=minutes&startDate=20200101&endDate=20200201&interval=60&order=asc&sessionFilter=EFK&splits=true÷nds=true&volume=sum&nearby=1&jerq=true"

myobj = {
    'apikey':'958bd129b997922724b5242bdcc8cf9d',
}

x = requests.post(urlPost, data = myobj)

f = open("dataset2.csv", "w")
f.write(x.text)
f.close()

# %%
urlPost = "https://marketdata.websol.barchart.com/getHistory.csv"

# %%
dataframe = pd.read_csv("dataset.csv")

# %%
dataframe[0:5]
# Out:
#   symbol                  timestamp  tradingDay      open      high       low  \
# 0    IBM  2020-04-30T09:00:00-04:00  2020-04-30  124.8457  125.1516  123.5629
# 1    IBM  2020-04-30T10:00:00-04:00  2020-04-30  125.0233  125.5857  123.9773
# 2    IBM  2020-04-30T11:00:00-04:00  2020-04-30  124.4608  125.0134  124.0661
# 3    IBM  2020-04-30T12:00:00-04:00  2020-04-30  124.1747  124.6286  123.6320
# 4    IBM  2020-04-30T13:00:00-04:00  2020-04-30  124.4310  124.4891  123.8836
#
#       close  volume
# 0  125.0184  630923
# 1  124.4411  618914
# 2  124.1944  504043
# 3  124.4806  465759
# 4  124.0069  321820

# %%
dataframe.describe()
# Out:
#              open        high         low       close        volume
# count  140.000000  140.000000  140.000000  140.000000  1.400000e+02
# mean   121.007309  121.468799  120.482169  120.947014  4.330178e+05
# std      2.828653    2.754608    2.824377    2.796046  1.860959e+05
# min    112.430000  114.320000  111.810000  112.440000  1.674290e+05
# 25%    119.755000  120.117500  119.174900  119.347375  2.900125e+05
# 50%    121.515000  121.925000  121.058250  121.472500  3.870425e+05
# 75%    122.413950  122.812500  121.902500  122.380875  5.377115e+05
# max    126.870000  126.970000  125.495000  125.880000  1.153210e+06

# %%
dataframe["timestamp"] = pd.to_datetime(dataframe["timestamp"]).values.astype(np.int64) 
dataframe = dataframe.drop(["tradingDay"], axis=1)

dataframe['symbol'] = pd.factorize(dataframe['symbol'])[0] + 1

# %%
dataframe[0:5]
# Out:
#    symbol            timestamp      open      high       low     close  volume
# 0       1  1588251600000000000  124.8457  125.1516  123.5629  125.0184  630923
# 1       1  1588255200000000000  125.0233  125.5857  123.9773  124.4411  618914
# 2       1  1588258800000000000  124.4608  125.0134  124.0661  124.1944  504043
# 3       1  1588262400000000000  124.1747  124.6286  123.6320  124.4806  465759
# 4       1  1588266000000000000  124.4310  124.4891  123.8836  124.0069  321820

# %%
dataframe.describe()
# Out:
#        symbol     timestamp        open        high         low       close  \
# count   154.0  1.540000e+02  154.000000  154.000000  154.000000  154.000000
# mean      1.0  1.589338e+18  121.465147  121.934795  120.932926  121.397802
# std       0.0  7.922156e+14    3.078755    3.023452    3.065841    3.042789
# min       1.0  1.588079e+18  112.430000  114.320000  111.810000  112.440000
# 25%       1.0  1.588695e+18  119.957500  120.425000  119.742500  119.994925
# 50%       1.0  1.589342e+18  121.629350  122.155950  121.241900  121.589850
# 75%       1.0  1.589990e+18  123.242500  123.845675  122.915000  123.257500
# max       1.0  1.590692e+18  127.174400  127.598700  126.735300  127.174400
#
#              volume
# count  1.540000e+02
# mean   4.367710e+05
# std    1.885894e+05
# min    1.674290e+05
# 25%    3.000700e+05
# 50%    3.870425e+05
# 75%    5.421845e+05
# max    1.153210e+06

# %%
X = dataframe.drop(["close"], axis=1)
y = dataframe["close"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
nEpocas = 1000
steps_per_epoch = 10
VALIDATION_SIZE = 1
BATCH_SIZE = 16
checkpoint = "bestModelTextGen.hdf5"

# %%
def soft_acc(y_true, y_pred):
    return K.mean(K.equal(K.round(y_true), K.round(y_pred)))

model = Sequential()

model.add(Embedding(output_dim=64, input_dim=len (X.columns) ))

model.add(LSTM(32, return_sequences=True))

model.add(Dropout(0.5))

model.add(LSTM(32, return_sequences=False))

model.add(Dense(units=1, activation='linear'))

model.compile(loss='mean_absolute_error', optimizer='adam', metrics = ['mse', 'mae', 'mape', 'cosine'])

mc = ModelCheckpoint(checkpoint, monitor='loss', verbose=1, save_best_only=True, mode='min')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100, min_delta=0.000001)

# fit the model
compute_steps_per_epoch = lambda x: int(math.ceil(1. * x / BATCH_SIZE))
val_steps = compute_steps_per_epoch(VALIDATION_SIZE)

#batch_size = numero de execuções antes de atualizar os erros.
history = model.fit( X_train, y_train, epochs=nEpocas, steps_per_epoch=steps_per_epoch, callbacks=[es, mc], validation_steps = val_steps, validation_data=(X_test, y_test))
# Out:
# Train on 103 samples, validate on 51 samples
# Epoch 1/1000
# 10/10 [==============================] - 3s 286ms/step - loss: 121.3724 - mean_squared_error: 14739.2825 - mean_absolute_error: 121.3724 - mean_absolute_percentage_error: 99.9624 - cosine_proximity: -0.8796 - val_loss: 121.2410 - val_mean_squared_error: 14710.9561 - val_mean_absolute_error: 121.2410 - val_mean_absolute_percentage_error: 99.9044 - val_cosine_proximity: -1.0000
#
# Epoch 00001: loss improved from inf to 121.37243, saving model to bestModelTextGen.hdf5
# Epoch 2/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 121.1969 - mean_squared_error: 14696.7069 - mean_absolute_error: 121.1969 - mean_absolute_percentage_error: 99.8177 - cosine_proximity: -1.0000 - val_loss: 120.9517 - val_mean_squared_error: 14640.9004 - val_mean_absolute_error: 120.9517 - val_mean_absolute_percentage_error: 99.6659 - val_cosine_proximity: -1.0000
#
# Epoch 00002: loss improved from 121.37243 to 121.19689, saving model to bestModelTextGen.hdf5
# Epoch 3/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 120.6799 - mean_squared_error: 14571.7164 - mean_absolute_error: 120.6799 - mean_absolute_percentage_error: 99.3917 - cosine_proximity: -1.0000 - val_loss: 119.9837 - val_mean_squared_error: 14407.6865 - val_mean_absolute_error: 119.9837 - val_mean_absolute_percentage_error: 98.8676 - val_cosine_proximity: -1.0000
#
# Epoch 00003: loss improved from 121.19689 to 120.67991, saving model to bestModelTextGen.hdf5
# Epoch 4/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 118.8896 - mean_squared_error: 14143.5053 - mean_absolute_error: 118.8896 - mean_absolute_percentage_error: 97.9164 - cosine_proximity: -1.0000 - val_loss: 116.9137 - val_mean_squared_error: 13680.4004 - val_mean_absolute_error: 116.9137 - val_mean_absolute_percentage_error: 96.3358 - val_cosine_proximity: -1.0000
#
# Epoch 00004: loss improved from 120.67991 to 118.88959, saving model to bestModelTextGen.hdf5
# Epoch 5/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 115.2530 - mean_squared_error: 13292.4817 - mean_absolute_error: 115.2530 - mean_absolute_percentage_error: 94.9198 - cosine_proximity: -1.0000 - val_loss: 113.1655 - val_mean_squared_error: 12818.0225 - val_mean_absolute_error: 113.1655 - val_mean_absolute_percentage_error: 93.2448 - val_cosine_proximity: -1.0000
#
# Epoch 00005: loss improved from 118.88959 to 115.25302, saving model to bestModelTextGen.hdf5
# Epoch 6/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 112.6967 - mean_squared_error: 12708.6769 - mean_absolute_error: 112.6967 - mean_absolute_percentage_error: 92.8132 - cosine_proximity: -1.0000 - val_loss: 112.1360 - val_mean_squared_error: 12586.0586 - val_mean_absolute_error: 112.1360 - val_mean_absolute_percentage_error: 92.3957 - val_cosine_proximity: -1.0000
#
# Epoch 00006: loss improved from 115.25302 to 112.69669, saving model to bestModelTextGen.hdf5
# Epoch 7/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 111.9596 - mean_squared_error: 12543.0075 - mean_absolute_error: 111.9596 - mean_absolute_percentage_error: 92.2057 - cosine_proximity: -1.0000 - val_loss: 111.6003 - val_mean_squared_error: 12466.2207 - val_mean_absolute_error: 111.6003 - val_mean_absolute_percentage_error: 91.9540 - val_cosine_proximity: -1.0000
#
# Epoch 00007: loss improved from 112.69669 to 111.95964, saving model to bestModelTextGen.hdf5
# Epoch 8/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 111.4422 - mean_squared_error: 12427.4065 - mean_absolute_error: 111.4422 - mean_absolute_percentage_error: 91.7794 - cosine_proximity: -1.0000 - val_loss: 111.1132 - val_mean_squared_error: 12357.7246 - val_mean_absolute_error: 111.1132 - val_mean_absolute_percentage_error: 91.5523 - val_cosine_proximity: -1.0000
#
# Epoch 00008: loss improved from 111.95964 to 111.44224, saving model to bestModelTextGen.hdf5
# Epoch 9/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 110.9661 - mean_squared_error: 12321.4993 - mean_absolute_error: 110.9661 - mean_absolute_percentage_error: 91.3870 - cosine_proximity: -1.0000 - val_loss: 110.6518 - val_mean_squared_error: 12255.4141 - val_mean_absolute_error: 110.6518 - val_mean_absolute_percentage_error: 91.1718 - val_cosine_proximity: -1.0000
#
# Epoch 00009: loss improved from 111.44224 to 110.96606, saving model to bestModelTextGen.hdf5
# Epoch 10/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 110.5141 - mean_squared_error: 12221.3981 - mean_absolute_error: 110.5141 - mean_absolute_percentage_error: 91.0146 - cosine_proximity: -1.0000 - val_loss: 110.2109 - val_mean_squared_error: 12158.0234 - val_mean_absolute_error: 110.2109 - val_mean_absolute_percentage_error: 90.8082 - val_cosine_proximity: -1.0000
#
# Epoch 00010: loss improved from 110.96606 to 110.51411, saving model to bestModelTextGen.hdf5
# Epoch 11/1000
# 10/10 [==============================] - 0s 16ms/step - loss: 110.0804 - mean_squared_error: 12125.7275 - mean_absolute_error: 110.0804 - mean_absolute_percentage_error: 90.6572 - cosine_proximity: -1.0000 - val_loss: 109.7856 - val_mean_squared_error: 12064.4697 - val_mean_absolute_error: 109.7856 - val_mean_absolute_percentage_error: 90.4575 - val_cosine_proximity: -1.0000
#
# Epoch 00011: loss improved from 110.51411 to 110.08041, saving model to bestModelTextGen.hdf5
# Epoch 12/1000
# 10/10 [==============================] - 0s 15ms/step - loss: 109.6609 - mean_squared_error: 12033.5311 - mean_absolute_error: 109.6609 - mean_absolute_percentage_error: 90.3114 - cosine_proximity: -1.0000 - val_loss: 109.3725 - val_mean_squared_error: 11973.9297 - val_mean_absolute_error: 109.3725 - val_mean_absolute_percentage_error: 90.1168 - val_cosine_proximity: -1.0000
#
# Epoch 00012: loss improved from 110.08041 to 109.66086, saving model to bestModelTextGen.hdf5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-bab209a8cda2> in <module>
#      24
#      25 #batch_size = numero de execuções antes de atualizar os erros.
# ---> 26 history = model.fit( X_train, y_train, epochs=nEpocas, steps_per_epoch=steps_per_epoch, callbacks=[es, mc], validation_steps = val_steps, validation_data=(X_test, y_test))
#
# c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     215                         for l, o in zip(out_labels, val_outs):
#     216                             epoch_logs['val_' + l] = o
# --> 217         callbacks.on_epoch_end(epoch, epoch_logs)
#     218         if callback_model.stop_training:
#     219             break
#
# c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#      77         logs = logs or {}
#      78         for callback in self.callbacks:
# ---> 79             callback.on_epoch_end(epoch, logs)
#      80
#      81     def on_batch_begin(self, batch, logs=None):
#
# c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     444                             self.model.save_weights(filepath, overwrite=True)
#     445                         else:
# --> 446                             self.model.save(filepath, overwrite=True)
#     447                     else:
#     448                         if self.verbose > 0:
#
# c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\engine\network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\engine\saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# c:\users\t-gamer\documents\git\projetomachinelearningregressao\venv\lib\site-packages\keras\engine\saving.py in _serialize_model(model, f, include_optimizer)
#     112         layer_group['weight_names'] = weight_names
#     113         for name, val in zip(weight_names, weight_values):
# --> 114             layer_group[name] = val
#     115     if include_optimizer and model.optimizer:
#     116         if isinstance(model.optimizer, optimizers.TFOptimizer):
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('mean_squared_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('mean_absolute_percentage_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['cosine_proximity'])
plt.plot(history.history['val_cosine_proximity'])
plt.title('cosine_proximity')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
